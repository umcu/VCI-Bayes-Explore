# %% [markdown]
# # VCI Bayes Explore

# %% [markdown]
# ## 1. Environment Setup
#
# Import dependencies, configure plotting defaults, and align pyAgrum's visual output.

# %%
# Core Python utilities
import base64
import io
import os
import random
from itertools import product
from pathlib import Path

# Numerical and data processing
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Visualisation helpers
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from IPython.display import display
from ipywidgets import interact, fixed

# Bayesian network tooling (pyAgrum ecosystem)
import pyagrum as gum
import pyagrum.lib.explain as explain
import pyagrum.lib.explain as expl
import pyagrum.lib.notebook as gnb
import pyagrum.lib.utils as gutils
import pyagrum.lib.bn2graph as gumb2g
import pyagrum.lib.bn_vs_bn as bnvsbn
import pyagrum.lib.bn_vs_bn as gcm
from pyagrum import BNLearner
from pyagrum.lib.bn2roc import showROC
from pyagrum.lib.discreteTypeProcessor import DiscreteTypeProcessor
import pyagrum.skbn as skbn
from pyagrum.skbn import BNClassifier

# Scikit-learn helpers
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import warnings

# Matplotlib defaults for manuscript-ready figures
warnings.filterwarnings('ignore', category=UserWarning)

mpl.rcParams['font.family'] = 'Helvetica Neue'
mpl.rcParams['font.size'] = 14
mpl.rcParams['font.weight'] = 'regular'

# %%
# Utility: format dictionaries for side-by-side HTML display in the notebook
def dict2html(di1, di2=None):
  res = "<br/>".join([f"<b>{k:15}</b>:{v}" for k, v in di1.items()])
  if di2 is not None:
    res += "<br/><br/>"
    res += "<br/>".join([f"<b>{k:15}</b>:{v}" for k, v in di2.items()])
  return res

# %%
# Ensure pyAgrum renders graphs with consistent layouts across reruns
gum.config["notebook", "graph_layout"] = "dot"
gum.config["notebook", "graph_rankdir"] = "TB"

# %% [markdown]
# ## 2. Data Loading and Preparation
#
# Set `PROJECT_ROOT` so that `PROJECT_ROOT / data` holds the parquet exports required for the analysis, or run `projects/HBC/preprocess_data.py` after configuring `config/data_paths.yml` to recreate them.
#
# This notebook expects three inputs:
# - `df.parquet`: raw cohort data without imputation (used for comparison plots).
# - `df_imp.parquet`: fully imputed dataset feeding the Bayesian network learner.
# - `bn_vars.parquet`: metadata table with at least `LAYER` and `VARIABLE NAME` columns describing the expert-assigned layer of each variable.
#
# Update the configuration cell below if your repository layout differs.

# %%
import os
from pathlib import Path

PROJECT_ROOT = Path.cwd()


def _get_path_override(key: str, project_root: Path) -> Path | None:
    """Return path override from env var or .env without hard-coding paths."""
    env_value = os.environ.get(key)
    if env_value:
        return Path(env_value).expanduser()

    env_path = project_root / '.env'
    if not env_path.exists():
        return None

    for raw_line in env_path.read_text().splitlines():
        line = raw_line.strip()
        if not line or line.startswith('#') or '=' not in line:
            continue
        name, value = line.split('=', 1)
        if name.strip() == key:
            cleaned = value.strip()
            if cleaned[:1] in {'"', "'"} and cleaned[-1:] == cleaned[:1]:
                cleaned = cleaned[1:-1]
            if cleaned:
                return Path(cleaned).expanduser()
    return None


candidate_dirs = []

override_path = _get_path_override('BAYESIAN_DATA_DIR', PROJECT_ROOT)
if override_path:
    if not override_path.exists():
        raise FileNotFoundError(
            f"BAYESIAN_DATA_DIR={str(override_path)!r} does not exist. "
            "Update the override value or remove it."
        )
    candidate_dirs.append(override_path)

candidate_dirs += [
    PROJECT_ROOT / 'src' / 'out',
    PROJECT_ROOT / 'out',
    PROJECT_ROOT / 'data',
]

for candidate in candidate_dirs:
    if candidate.exists():
        DATA_DIR = candidate
        break
else:
    DATA_DIR = PROJECT_ROOT / 'data'

# %%
# Load harmonised datasets used throughout the analysis
df = pd.read_parquet(DATA_DIR / 'df.parquet', engine='pyarrow')
df_imp = pd.read_parquet(DATA_DIR / 'df_imp.parquet', engine='pyarrow')
bn_vars = pd.read_parquet(DATA_DIR / 'bn_vars.parquet', engine='pyarrow')

# %%
df_imp.head()
# Out:
#          AGE     SEX   PTAU181        NFL        GFAP        AB40       AB42  \
# 0  58.929500  Female  2.167700  11.135018  153.128545  109.304989   6.956860
# 1  57.464750    Male  0.951074  12.241553  105.655261  113.991180   5.197182
# 2  62.464066    Male  0.944169  17.346210   69.483929  100.077280   6.615191
# 3  81.475702  Female  3.123887  38.966101   93.721259  144.314806  11.023838
# 4  85.483915  Female  3.308229  47.927891  180.980266  129.650860   8.041534
#
#    MINI MENTAL STATE EXAMINATION  STARKSTEIN SCORE BASELINE CDR  ...  \
# 0                           29.0              17.0          0.5  ...
# 1                           28.0               7.0          0.5  ...
# 2                           29.0              15.0          0.5  ...
# 3                           24.0               9.0            0  ...
# 4                           27.0              14.0          0.5  ...
#
#   BIOMARKER SCORE 2 HIPPOCAMPUS/INTRACRANIAL VOLUME  \
# 0         -0.295161                        0.296111
# 1         -0.516713                        0.284456
# 2          0.197913                        0.232088
# 3         -0.027096                        0.261467
# 4          0.442229                        0.271217
#
#    BRAIN/INTRACRANIAL VOLUME  CEREBRAL BLOOD FLOW  \
# 0                  82.956121              55.5574
# 1                  85.009808              50.0680
# 2                  75.070512              56.1078
# 3                  74.981904              55.5076
# 4                  75.197876              71.3985
#
#    ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY  OUTCOME_MACE  \
# 0                                              No    Unobserved
# 1                                              No            No
# 2                                             Yes    Unobserved
# 3                                             Yes    Unobserved
# 4                                              No    Unobserved
#
#    OUTCOME_CDR_INCREASE DROPOUT REASON VASCULAR RISK SCORE  \
# 0            Unobserved          Other                 3.6
# 1                    No     No dropout                 6.1
# 2            Unobserved        Refusal                 6.2
# 3            Unobserved        Refusal                27.0
# 4            Unobserved       Deceased                19.6
#
#                    PATIENT GROUP
# 0  Vascular cognitive impairment
# 1  Vascular cognitive impairment
# 2                  Heart failure
# 3                  Heart failure
# 4                  Heart failure
#
# [5 rows x 23 columns]

# %%
# Harmonise categorical entries before discretisation
for frame in (df, df_imp):
    # Replace blank or missing stroke history entries with explicit 'No'
    if 'STROKE HISTORY' in frame.columns:
        frame['STROKE HISTORY'] = frame['STROKE HISTORY'].replace({'': 'No', ' ': 'No'}).fillna('No')
    # Legacy CVA column cleaning (if present)
    if 'CVA' in frame.columns:
        frame['CVA'] = frame['CVA'].replace({'': 'Nee', ' ': 'Nee'}).fillna('Nee')
# Out:
# /var/folders/k7/m876w0ts2n77lwt3x1dc25zc0000gp/T/ipykernel_4189/4040133624.py:8: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   frame['CVA'] = frame['CVA'].replace({'': 'Nee', ' ': 'Nee'}).fillna('Nee')

# %% [markdown]
# ### 2.2 Metadata sanity check
# The `bn_vars` table should map every variable used in the network to its corresponding layer.
# If you add new variables, ensure the parquet file lists them with the desired `LAYER` label.

# %% [markdown]
# Example `bn_vars.parquet` structure (first columns):
#
# | LAYER | VARIABLE NAME | DESCRIPTION |
# | --- | --- | --- |
# | L0 – Unmodifiable demographics | AGE | Baseline age in years |
# | L0 – Unmodifiable demographics | SEX | Biological sex at baseline |
# | L2 – Cardiovascular risk factors | VASCULAR RISK SCORE | SCORE2 cardiovascular risk estimate |
# | L4 – Potential disease process markers | PTAU181 | Plasma pTau181 concentration category |
# | L6 – Current and previous cardiovascular diagnoses / Vascular interventions | PATIENT GROUP | Diagnostic cohort label |
# | L8 – Outcomes | OUTCOME_MACE | Binary indicator of follow-up MACE |
#
# Add extra columns (e.g. `DISPLAY NAME`, `NOTES`) as needed—the loader only requires `LAYER` and `VARIABLE NAME`.

# %%
# Ensure DROPOUT REASON is mapped to the dropout layer
if 'bn_vars' in globals():
    if 'DROPOUT REASON' not in bn_vars['VARIABLE NAME'].values:
        bn_vars = pd.concat([bn_vars, pd.DataFrame([{'LAYER': 'L9 – Dropout', 'VARIABLE NAME': 'DROPOUT REASON'}])], ignore_index=True)
    else:
        bn_vars.loc[bn_vars['VARIABLE NAME'] == 'DROPOUT REASON', 'LAYER'] = 'L9 – Dropout'

# %%
# Preview the first few rows once bn_vars.parquet is loaded
bn_vars.sort_values(['LAYER', 'VARIABLE NAME'])
# Out:
#                                                 LAYER  \
# 13                     L0 – Unmodifiable demographics
# 14                     L0 – Unmodifiable demographics
# 22                   L2 – Cardiovascular risk factors
# 19             L4 – Potential disease process markers
# 20             L4 – Potential disease process markers
# 4              L4 – Potential disease process markers
# 5              L4 – Potential disease process markers
# 9              L4 – Potential disease process markers
# 17             L4 – Potential disease process markers
# 16             L4 – Potential disease process markers
# 15             L4 – Potential disease process markers
# 8        L5 - Imaging markers of neurovascular damage
# 7        L5 - Imaging markers of neurovascular damage
# 6        L5 - Imaging markers of neurovascular damage
# 21  L6 – Current and previous cardiovascular diagn...
# 18  L6 – Current and previous cardiovascular diagn...
# 3   L6 – Current and previous cardiovascular diagn...
# 2                              L7 - Functional status
# 0                              L7 - Functional status
# 1                              L7 - Functional status
# 10                                      L8 – Outcomes
# 12                                      L8 – Outcomes
# 11                                       L9 – Dropout
#
#                                      VARIABLE NAME
# 13                                             AGE
# 14                                             SEX
# 22                             VASCULAR RISK SCORE
# 19                                            AB40
# 20                                            AB42
# 4                                BIOMARKER SCORE 1
# 5                                BIOMARKER SCORE 2
# 9                              CEREBRAL BLOOD FLOW
# 17                                            GFAP
# 16                                             NFL
# 15                                         PTAU181
# 8                        BRAIN/INTRACRANIAL VOLUME
# 7                  HIPPOCAMPUS/INTRACRANIAL VOLUME
# 6                       SMALL VESSEL DISEASE SCORE
# 21  ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY
# 18                                   PATIENT GROUP
# 3                                   STROKE HISTORY
# 2                                     BASELINE CDR
# 0                    MINI MENTAL STATE EXAMINATION
# 1                                 STARKSTEIN SCORE
# 10                            OUTCOME_CDR_INCREASE
# 12                                    OUTCOME_MACE
# 11                                  DROPOUT REASON

# %%
# Validate the metadata layout before building the network
expected_columns = {'LAYER', 'VARIABLE NAME'}
missing_cols = expected_columns - set(bn_vars.columns)
if missing_cols:
    raise ValueError(f"bn_vars is missing required columns: {missing_cols}")

print('Layers discovered in bn_vars:', sorted(bn_vars['LAYER'].unique()))
display(bn_vars.head())
# Out:
# Layers discovered in bn_vars: ['L0 – Unmodifiable demographics', 'L2 – Cardiovascular risk factors', 'L4 – Potential disease process markers', 'L5 - Imaging markers of neurovascular damage', 'L6 – Current and previous cardiovascular diagnoses / Vascular interventions', 'L7 - Functional status', 'L8 – Outcomes', 'L9 – Dropout']
#                                                LAYER  \
# 0                             L7 - Functional status
# 1                             L7 - Functional status
# 2                             L7 - Functional status
# 3  L6 – Current and previous cardiovascular diagn...
# 4             L4 – Potential disease process markers
#
#                    VARIABLE NAME
# 0  MINI MENTAL STATE EXAMINATION
# 1               STARKSTEIN SCORE
# 2                   BASELINE CDR
# 3                 STROKE HISTORY
# 4              BIOMARKER SCORE 1

# %% [markdown]
# ## 3. Variable Discretisation
#
# Configure the binning strategy feeding each learner and inspect the resulting template.

# %%
# Configure discretisation defaults for mixed-type clinical variables
type_processor = DiscreteTypeProcessor(
  defaultDiscretizationMethod="quantile", defaultNumberOfBins=4, discretizationThreshold=10
)

# %%
# Inspect the discretised template to document the bins used by the learner
# creating a template explaining the variables proposed by the type_processor. This variables will be used by the learner
template = type_processor.discretizedTemplate(df_imp)
for i, n in template:
  print(f"{n:7} : {template.variable(i)}")
# Out:
# AGE     : AGE:Discretized(<(48.4928;61.5777[,[61.5777;68.0452[,[68.0452;73.6283[,[73.6283;92.4983)>)
# SEX     : SEX:Labelized({Female|Male})
# PTAU181 : PTAU181:Discretized(<(0.333625;1.23182[,[1.23182;1.56711[,[1.56711;2.19498[,[2.19498;11.0239)>)
# NFL     : NFL:Discretized(<(4.43247;13.0649[,[13.0649;17.9933[,[17.9933;26.4446[,[26.4446;309.426)>)
# GFAP    : GFAP:Discretized(<(21.5563;65.217[,[65.217;93.557[,[93.557;135.107[,[135.107;676.236)>)
# AB40    : AB40:Discretized(<(8.19715;86.9946[,[86.9946;99.9314[,[99.9314;112.96[,[112.96;263.656)>)
# AB42    : AB42:Discretized(<(0.510692;5.59224[,[5.59224;6.50279[,[6.50279;7.68149[,[7.68149;17.5025)>)
# MINI MENTAL STATE EXAMINATION : MINI MENTAL STATE EXAMINATION:Discretized(<(15;27[,[27;29[,[29;30)>)
# STARKSTEIN SCORE : STARKSTEIN SCORE:Discretized(<(0;6[,[6;9[,[9;12[,[12;32)>)
# BASELINE CDR : BASELINE CDR:NumericalDiscrete({0|0.5|1})
# STROKE HISTORY : STROKE HISTORY:Labelized({No|Yes, hemorrhagic stroke|Yes, ischemic stroke|Yes, type unknown})
# SMALL VESSEL DISEASE SCORE : SMALL VESSEL DISEASE SCORE:Range([0,4])
# BIOMARKER SCORE 1 : BIOMARKER SCORE 1:Discretized(<(-1.73101;-0.395125[,[-0.395125;-0.0218966[,[-0.0218966;0.406606[,[0.406606;3.89712)>)
# BIOMARKER SCORE 2 : BIOMARKER SCORE 2:Discretized(<(-11.1;-0.46179[,[-0.46179;0.0323929[,[0.0323929;0.601864[,[0.601864;13.5)>)
# HIPPOCAMPUS/INTRACRANIAL VOLUME : HIPPOCAMPUS/INTRACRANIAL VOLUME:Discretized(<(0.159529;0.251299[,[0.251299;0.27252[,[0.27252;0.296034[,[0.296034;0.374626)>)
# BRAIN/INTRACRANIAL VOLUME : BRAIN/INTRACRANIAL VOLUME:Discretized(<(66.6072;75.8592[,[75.8592;78.7694[,[78.7694;80.8899[,[80.8899;86.0034)>)
# CEREBRAL BLOOD FLOW : CEREBRAL BLOOD FLOW:Discretized(<(30.6517;44.1538[,[44.1538;51.421[,[51.421;59.5652[,[59.5652;90.2401)>)
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY : ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY:Labelized({No|Yes})
# OUTCOME_MACE : OUTCOME_MACE:Labelized({No|Unobserved|Yes})
# OUTCOME_CDR_INCREASE : OUTCOME_CDR_INCREASE:Labelized({No|Unobserved|Yes})
# DROPOUT REASON : DROPOUT REASON:Labelized({Deceased|Moved to Nursing Home|No dropout|Other|Refusal|Too Ill|Untraceable})
# VASCULAR RISK SCORE : VASCULAR RISK SCORE:Discretized(<(0.8;5.5[,[5.5;8.25[,[8.25;12.975[,[12.975;38.5)>)
# PATIENT GROUP : PATIENT GROUP:Labelized({Carotid occlusive disease|Heart failure|Reference|Vascular cognitive impairment})

# %%
# Inspect the discretised template to document the bins used by the learner
template = type_processor.discretizedTemplate(df_imp)

def format_label(label):
    parts = label.strip('([)').split(';')
    lower = float(parts[0])
    upper = float(parts[1].replace('[', '').replace(')', ''))

    lower_rounded = round(lower, 1)
    upper_rounded = round(upper, 1)

    return f"({lower_rounded};{upper_rounded}["

for i, n in template:
    var = template.variable(i)
    labels = var.labels()

    # Check if the labels look like intervals
    if all((";" in label and "[" in label) for label in labels):
        formatted_labels = [format_label(label) for label in labels]
        print(f"{n:7} : {formatted_labels}")
    else:
        print(f"{n:7} : {labels}")
# Out:
# AGE     : ['(48.5;61.6[', '(61.6;68.0[', '(68.0;73.6[', '(73.6;92.5[']
# SEX     : ('Female', 'Male')
# PTAU181 : ['(0.3;1.2[', '(1.2;1.6[', '(1.6;2.2[', '(2.2;11.0[']
# NFL     : ['(4.4;13.1[', '(13.1;18.0[', '(18.0;26.4[', '(26.4;309.4[']
# GFAP    : ['(21.6;65.2[', '(65.2;93.6[', '(93.6;135.1[', '(135.1;676.2[']
# AB40    : ['(8.2;87.0[', '(87.0;99.9[', '(99.9;113.0[', '(113.0;263.7[']
# AB42    : ['(0.5;5.6[', '(5.6;6.5[', '(6.5;7.7[', '(7.7;17.5[']
# MINI MENTAL STATE EXAMINATION : ['(15.0;27.0[', '(27.0;29.0[', '(29.0;30.0[']
# STARKSTEIN SCORE : ['(0.0;6.0[', '(6.0;9.0[', '(9.0;12.0[', '(12.0;32.0[']
# BASELINE CDR : ('0', '0.5', '1')
# STROKE HISTORY : ('No', 'Yes, hemorrhagic stroke', 'Yes, ischemic stroke', 'Yes, type unknown')
# SMALL VESSEL DISEASE SCORE : ('0', '1', '2', '3', '4')
# BIOMARKER SCORE 1 : ['(-1.7;-0.4[', '(-0.4;-0.0[', '(-0.0;0.4[', '(0.4;3.9[']
# BIOMARKER SCORE 2 : ['(-11.1;-0.5[', '(-0.5;0.0[', '(0.0;0.6[', '(0.6;13.5[']
# HIPPOCAMPUS/INTRACRANIAL VOLUME : ['(0.2;0.3[', '(0.3;0.3[', '(0.3;0.3[', '(0.3;0.4[']
# BRAIN/INTRACRANIAL VOLUME : ['(66.6;75.9[', '(75.9;78.8[', '(78.8;80.9[', '(80.9;86.0[']
# CEREBRAL BLOOD FLOW : ['(30.7;44.2[', '(44.2;51.4[', '(51.4;59.6[', '(59.6;90.2[']
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY : ('No', 'Yes')
# OUTCOME_MACE : ('No', 'Unobserved', 'Yes')
# OUTCOME_CDR_INCREASE : ('No', 'Unobserved', 'Yes')
# DROPOUT REASON : ('Deceased', 'Moved to Nursing Home', 'No dropout', 'Other', 'Refusal', 'Too Ill', 'Untraceable')
# VASCULAR RISK SCORE : ['(0.8;5.5[', '(5.5;8.2[', '(8.2;13.0[', '(13.0;38.5[']
# PATIENT GROUP : ('Carotid occlusive disease', 'Heart failure', 'Reference', 'Vascular cognitive impairment')

# %%
# Optional: uncomment to audit discretisation results
#auditDict = type_processor.audit(df_imp)

#print()
#print("** audit **")
#for var in auditDict:
#  print(f"- {var} : ")
#  for k, v in auditDict[var].items():
#    print(f"    + {k} : {v}")

# %% [markdown]
# ## 4. Knowledge-Guided Network Definition
#
# Translate the expert-defined layers into a reusable Bayesian network template.

# %%
# Map variables onto expert-defined layers for downstream constraints
layer_map = (
    bn_vars.groupby('LAYER')['VARIABLE NAME']
    .apply(list)
    .to_dict()
)

# %%
# Instantiate the Bayesian network using the discretised template as blueprint
bn = gum.BayesNet("LayeredBN")
node_ids = {}

for i in range(template.size()):
    var = template.variable(i)
    name = var.name()
    node_ids[name] = bn.add(var)  # only add once, from template

# %%
# Preserve the expert-defined order of layers when applying constraints
# Make sure keys are in the correct order
layer_keys = list(layer_map.keys())  # use list, not sorted, to preserve domain-defined order

# %% [markdown]
# ## 5. Constrained Structure Learning
#
# Estimate networks that respect the layer order while testing different outcome configurations.

# %%
# Utility: learn a Bayesian network with optional guided structure constraints
import random
from itertools import product


def configure_guided_structure(learner, layer_map_filtered, variables_to_keep, outcomes, enforce=True):
    """Apply dropout-aware arc constraints when enforce=True."""
    layer_keys = list(layer_map_filtered.keys())
    dropout_layer_keys = [k for k in layer_keys if "Dropout" in k]
    dropout_vars = [var for key in dropout_layer_keys for var in layer_map_filtered[key]]
    true_outcomes = [var for var in outcomes if "DROPOUT" not in var.upper()]

    if not enforce:
        return dropout_vars, true_outcomes

    allowed_arcs = []
    for i, from_key in enumerate(layer_keys):
        from_vars = layer_map_filtered[from_key]
        for to_key in layer_keys[i:]:
            to_vars = layer_map_filtered[to_key]
            for parent, child in product(from_vars, to_vars):
                if child in dropout_vars:
                    if parent in outcomes:
                        allowed_arcs.append((parent, child))
                    continue
                if parent in variables_to_keep and child in variables_to_keep:
                    allowed_arcs.append((parent, child))

    for parent in variables_to_keep:
        for child in variables_to_keep:
            if parent != child and (parent, child) not in allowed_arcs:
                learner.addForbiddenArc(parent, child)

    for parent in true_outcomes:
        for child in true_outcomes:
            if parent != child:
                learner.addForbiddenArc(parent, child)

    return dropout_vars, true_outcomes


def build_bn(df, outcomes, layer_map, type_processor, score='K2', use_tabu=True, random_seed=42, enforce_structure=True):

    random.seed(random_seed)
    np.random.seed(random_seed)

    # Step 0: Exclude 'L4 – Potential disease process markers'
    layer_map_filtered = {k: v for k, v in layer_map.items() if k != 'L4 – Potential disease process markers'}
    excluded_vars = layer_map.get('L4 – Potential disease process markers', [])

    # Step 1: Drop excluded outcome variables and excluded biomarkers
    outcomes_all_layers = [v for k, v in layer_map.items() if "Outcomes" in k or "Dropout" in k]
    outcomes_flat = [var for sublist in outcomes_all_layers for var in sublist]
    drop_outcomes = list(set(outcomes_flat) - set(outcomes))

    df_reduced = df.drop(columns=drop_outcomes + excluded_vars, errors='ignore')
    variables_to_keep = df_reduced.columns.tolist()

    # Step 2: Build template from reduced dataframe
    template_reduced = type_processor.discretizedTemplate(df_reduced)

    # Step 3: Instantiate the learner
    learner = gum.BNLearner(df_reduced, template_reduced)

    if score.upper() == 'K2':
        learner.useScoreK2()
    elif score.upper() == 'BIC':
        learner.useScoreBIC()
        learner.useSmoothingPrior()
    elif score.upper() == "BDEU":
        learner.useScoreBDeu(ess=1)
    else:
        raise ValueError("Unsupported score method: choose 'K2' or 'BIC'")

    if use_tabu:
        learner.useLocalSearchWithTabuList()
    else:
        learner.useGreedyHillClimbing()

    # Step 4: Optionally apply guided structure constraints
    dropout_vars, true_outcomes = configure_guided_structure(
        learner,
        layer_map_filtered,
        variables_to_keep,
        outcomes,
        enforce=enforce_structure,
    )

    learner.setMaxIndegree(5)
    # Step 7: Learn the network
    bn = learner.learnBN()
    # Step 8: Ensure outcomes point to dropout layer when enforcing guidance
    if enforce_structure:
        try:
            dropout_ids = [bn.idFromName(name) for name in dropout_vars if name in bn.names()]
            outcome_ids = [bn.idFromName(name) for name in true_outcomes if name in bn.names()]
            for drop_id in dropout_ids:
                for out_id in outcome_ids:
                    if not bn.existsArc(out_id, drop_id):
                        bn.addArc(out_id, drop_id)
        except gum.InvalidArgument:
            pass

    return bn

# %%
bn_cdr = build_bn(df_imp, outcomes=["OUTCOME_CDR_INCREASE", "DROPOUT REASON"], layer_map=layer_map, type_processor=type_processor, score="K2")
bn_mace = build_bn(df_imp, outcomes=["OUTCOME_MACE", "DROPOUT REASON"], layer_map=layer_map, type_processor=type_processor, score="K2")
bn_joint = build_bn(df_imp, outcomes=["OUTCOME_CDR_INCREASE", "OUTCOME_MACE", "DROPOUT REASON"], layer_map=layer_map, type_processor=type_processor, score="K2")

# %%
# Define your ordered layers and assign them increasing color intensity
layer_order = [
    'L0 – Unmodifiable demographics',
    'L1 – Modifiable demograhpics / Lifestyle factors',
    'L2 – Cardiovascular risk factors',
    'L4 – Potential disease process markers',
    'L5 - Imaging markers of neurovascular damage',
    'L6 – Current and previous cardiovascular diagnoses / Vascular interventions',
    'L7 - Functional status',
    'L8 – Outcomes',
    'L9 – Dropout'
]

# Set adjusted min and max color values
min_color_val = 0.111111
max_color_val = 0.99999
steps = len(layer_order) - 1

# Create adjusted color intensity map
layer_color_map = {
    name: min_color_val + i * (max_color_val - min_color_val) / steps
    for i, name in enumerate(layer_order)
}

# Build the nodeColor dictionary
node_colors = {}
for layer_name, variables in layer_map.items():
    color_val = layer_color_map.get(layer_name, 0.5)  # fallback if unknown
    for var in variables:
        if var in bn_joint.names():
            node_colors[var] = color_val

# %%
# Bootstrap helper: quantify edge stability across resampled datasets
from collections import defaultdict
def bootstrap_edge_frequencies(df, outcomes, layer_map, type_processor,
                                build_bn_func, n_bootstraps=100, score='K2', use_tabu=True, random_seed=42):
    edge_counts = defaultdict(int)

    for i in range(n_bootstraps):
        seed = random_seed + i
        random.seed(seed)
        np.random.seed(seed)

        # Bootstrap resample
        boot_df = df.sample(frac=1.0, replace=True, random_state=seed)

        try:
            bn = build_bn_func(boot_df, outcomes, layer_map, type_processor,
                               score=score, use_tabu=use_tabu, random_seed=seed)
        except Exception as e:
            print(f"Bootstrap {i} failed: {e}")
            continue

        # Count arcs
        for parent_id, child_id in bn.arcs():
            parent = bn.variable(parent_id).name()
            child = bn.variable(child_id).name()
            edge_counts[(parent, child)] += 1

    # Normalize to frequencies
    edge_frequencies = {edge: count / n_bootstraps for edge, count in edge_counts.items()}
    return edge_frequencies

# %%
edge_freqs = bootstrap_edge_frequencies(
    df=df_imp,
    outcomes=["OUTCOME_CDR_INCREASE", "OUTCOME_MACE", "DROPOUT REASON"],
    layer_map=layer_map,
    type_processor=type_processor,
    build_bn_func=build_bn,
    n_bootstraps=200,
    score='K2',
    use_tabu=True,
    random_seed=42
)

# Print top edges
for edge, freq in sorted(edge_freqs.items(), key=lambda x: -x[1]):
    print(f"{edge[0]} → {edge[1]}: {freq:.2f}")
# Out:
# PATIENT GROUP → BASELINE CDR: 1.00
# OUTCOME_MACE → DROPOUT REASON: 1.00
# AGE → VASCULAR RISK SCORE: 1.00
# PATIENT GROUP → OUTCOME_CDR_INCREASE: 1.00
# OUTCOME_CDR_INCREASE → DROPOUT REASON: 1.00
# SEX → VASCULAR RISK SCORE: 1.00
# SMALL VESSEL DISEASE SCORE → PATIENT GROUP: 0.98
# AGE → BRAIN/INTRACRANIAL VOLUME: 0.96
# VASCULAR RISK SCORE → BRAIN/INTRACRANIAL VOLUME: 0.96
# BASELINE CDR → MINI MENTAL STATE EXAMINATION: 0.96
# AGE → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.96
# SEX → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.95
# VASCULAR RISK SCORE → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.94
# PATIENT GROUP → OUTCOME_MACE: 0.90
# SMALL VESSEL DISEASE SCORE → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.88
# SEX → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.84
# PATIENT GROUP → STARKSTEIN SCORE: 0.83
# VASCULAR RISK SCORE → SMALL VESSEL DISEASE SCORE: 0.82
# SMALL VESSEL DISEASE SCORE → BRAIN/INTRACRANIAL VOLUME: 0.81
# SMALL VESSEL DISEASE SCORE → STARKSTEIN SCORE: 0.78
# BASELINE CDR → STARKSTEIN SCORE: 0.78
# BASELINE CDR → OUTCOME_CDR_INCREASE: 0.73
# BRAIN/INTRACRANIAL VOLUME → OUTCOME_MACE: 0.70
# BRAIN/INTRACRANIAL VOLUME → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.69
# MINI MENTAL STATE EXAMINATION → OUTCOME_CDR_INCREASE: 0.65
# SEX → BRAIN/INTRACRANIAL VOLUME: 0.60
# HIPPOCAMPUS/INTRACRANIAL VOLUME → STARKSTEIN SCORE: 0.60
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → PATIENT GROUP: 0.56
# PATIENT GROUP → STROKE HISTORY: 0.56
# VASCULAR RISK SCORE → OUTCOME_MACE: 0.55
# SMALL VESSEL DISEASE SCORE → OUTCOME_MACE: 0.55
# AGE → OUTCOME_CDR_INCREASE: 0.54
# AGE → OUTCOME_MACE: 0.52
# MINI MENTAL STATE EXAMINATION → OUTCOME_MACE: 0.51
# BRAIN/INTRACRANIAL VOLUME → STARKSTEIN SCORE: 0.50
# STROKE HISTORY → MINI MENTAL STATE EXAMINATION: 0.50
# VASCULAR RISK SCORE → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.46
# STROKE HISTORY → PATIENT GROUP: 0.45
# VASCULAR RISK SCORE → MINI MENTAL STATE EXAMINATION: 0.44
# PATIENT GROUP → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.44
# HIPPOCAMPUS/INTRACRANIAL VOLUME → OUTCOME_MACE: 0.41
# STROKE HISTORY → OUTCOME_CDR_INCREASE: 0.41
# BRAIN/INTRACRANIAL VOLUME → OUTCOME_CDR_INCREASE: 0.40
# PATIENT GROUP → MINI MENTAL STATE EXAMINATION: 0.40
# VASCULAR RISK SCORE → STARKSTEIN SCORE: 0.40
# AGE → STARKSTEIN SCORE: 0.39
# BRAIN/INTRACRANIAL VOLUME → PATIENT GROUP: 0.38
# VASCULAR RISK SCORE → OUTCOME_CDR_INCREASE: 0.35
# AGE → MINI MENTAL STATE EXAMINATION: 0.35
# SMALL VESSEL DISEASE SCORE → MINI MENTAL STATE EXAMINATION: 0.34
# HIPPOCAMPUS/INTRACRANIAL VOLUME → PATIENT GROUP: 0.34
# STARKSTEIN SCORE → OUTCOME_MACE: 0.32
# HIPPOCAMPUS/INTRACRANIAL VOLUME → BRAIN/INTRACRANIAL VOLUME: 0.32
# SEX → PATIENT GROUP: 0.31
# MINI MENTAL STATE EXAMINATION → STARKSTEIN SCORE: 0.30
# SEX → AGE: 0.29
# SMALL VESSEL DISEASE SCORE → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.29
# AGE → PATIENT GROUP: 0.28
# BRAIN/INTRACRANIAL VOLUME → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.27
# HIPPOCAMPUS/INTRACRANIAL VOLUME → MINI MENTAL STATE EXAMINATION: 0.27
# BRAIN/INTRACRANIAL VOLUME → MINI MENTAL STATE EXAMINATION: 0.26
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → OUTCOME_MACE: 0.23
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → MINI MENTAL STATE EXAMINATION: 0.23
# STROKE HISTORY → BASELINE CDR: 0.23
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → OUTCOME_CDR_INCREASE: 0.22
# STROKE HISTORY → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.22
# VASCULAR RISK SCORE → PATIENT GROUP: 0.20
# AGE → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.20
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → STARKSTEIN SCORE: 0.18
# SEX → STARKSTEIN SCORE: 0.17
# BASELINE CDR → OUTCOME_MACE: 0.17
# SMALL VESSEL DISEASE SCORE → OUTCOME_CDR_INCREASE: 0.17
# SEX → OUTCOME_CDR_INCREASE: 0.15
# SMALL VESSEL DISEASE SCORE → STROKE HISTORY: 0.15
# AGE → SEX: 0.15
# SEX → MINI MENTAL STATE EXAMINATION: 0.14
# AGE → SMALL VESSEL DISEASE SCORE: 0.14
# STARKSTEIN SCORE → MINI MENTAL STATE EXAMINATION: 0.12
# SEX → STROKE HISTORY: 0.12
# HIPPOCAMPUS/INTRACRANIAL VOLUME → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.12
# BRAIN/INTRACRANIAL VOLUME → BASELINE CDR: 0.10
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → BASELINE CDR: 0.10
# STARKSTEIN SCORE → OUTCOME_CDR_INCREASE: 0.10
# HIPPOCAMPUS/INTRACRANIAL VOLUME → SMALL VESSEL DISEASE SCORE: 0.09
# STROKE HISTORY → STARKSTEIN SCORE: 0.09
# SEX → SMALL VESSEL DISEASE SCORE: 0.08
# STROKE HISTORY → OUTCOME_MACE: 0.07
# SEX → OUTCOME_MACE: 0.07
# HIPPOCAMPUS/INTRACRANIAL VOLUME → OUTCOME_CDR_INCREASE: 0.04
# MINI MENTAL STATE EXAMINATION → BASELINE CDR: 0.04
# HIPPOCAMPUS/INTRACRANIAL VOLUME → BASELINE CDR: 0.02
# BRAIN/INTRACRANIAL VOLUME → SMALL VESSEL DISEASE SCORE: 0.02
# AGE → STROKE HISTORY: 0.01
# AGE → BASELINE CDR: 0.01

# %%
# Get the labels for CDR_INCR
cdr_labels = list(bn_joint.variable(bn_joint.idFromName("OUTCOME_CDR_INCREASE")).labels())
mace_labels = list(bn_joint.variable(bn_joint.idFromName("OUTCOME_MACE")).labels())

# %% [markdown]
# ## 6. Posterior Inference and Edge Stability
#
# Summarise how the learned networks behave under different evidence configurations and assess structural robustness.

# %% [markdown]
# ### 6.1 Posterior inference for CDR
#
# Visualise how upstream factors shift when conditioning on `OUTCOME_CDR_INCREASE`.

# %% [markdown]
# Condition the CDR network on each outcome modality to review the upstream clinical drivers.

# %%
gnb.sideBySide(
    *[
        gnb.showBN(bn_joint, size="9", nodeColor=node_colors, cmapNode=plt.get_cmap("coolwarm"))
    ],
    captions=[f"Inference given that CDR_INCREASE = {label}" for label in cdr_labels],
    ncols=1
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;">None<br><small><i>Inference given that CDR_INCREASE = No</i></small></div></td></tr><tr></tr></table>

# %% [markdown]
# ### 6.2 Joint inference for CDR and MACE
#
# Inspect posterior behaviour when conditioning on both outcome nodes simultaneously.

# %% [markdown]
# Focus on the parents of each outcome to summarise the conditional probability tables.

# %%
# Create inference engine
ie = gum.LazyPropagation(bn_joint)
ie.makeInference()

# Compute MI and apply it to arcs using variable indices (not names)
arc_width = {}

for u, v in bn_joint.arcs():  # u and v are variable IDs
    try:
        it = gum.InformationTheory(ie, v, [u])  # use IDs directly
        mi = it.mutualInformationXY()
    except:
        mi = 0.1

    arc_width[(u, v)] = mi  # ✅ use indices, not names

max_mi = max(arc_width.values())
arc_width = {k: (np.sqrt(v) / np.sqrt(max_mi) * 3.0 + 0.5) for k, v in arc_width.items()}

# %%
var_name_to_id = {bn_joint.variable(i).name(): i for i in range(bn_joint.size())}

bootstrap_freq_id = {}

for (parent_name, child_name), freq in edge_freqs.items():
    try:
        parent_id = var_name_to_id[parent_name]
        child_id = var_name_to_id[child_name]
        bootstrap_freq_id[(parent_id, child_id)] = freq
    except KeyError:
        continue  # skip if variable not found in network

# %%
arc_label = {
    arc: f"f={int(bootstrap_freq_id.get(arc, 0.0) * 100)}%"
    for arc in bn_joint.arcs()
}

# %%
arc_label
# Out:
# {(14, 4): 'f=100%',
#  (4, 3): 'f=77%',
#  (14, 10): 'f=89%',
#  (9, 14): 'f=56%',
#  (10, 12): 'f=100%',
#  (1, 9): 'f=84%',
#  (13, 8): 'f=96%',
#  (6, 14): 'f=98%',
#  (4, 2): 'f=96%',
#  (4, 11): 'f=73%',
#  (0, 7): 'f=96%',
#  (1, 5): 'f=12%',
#  (0, 13): 'f=100%',
#  (2, 10): 'f=51%',
#  (14, 11): 'f=100%',
#  (5, 14): 'f=44%',
#  (11, 12): 'f=100%',
#  (1, 13): 'f=100%',
#  (13, 6): 'f=82%',
#  (7, 8): 'f=31%'}

# %%
arc_color_values = {
    arc: bootstrap_freq_id.get(arc, 0.0)
    for arc in bn_joint.arcs()
}

# %%
# Plot with MI-based edge widths
gnb.showBN(
    bn_joint,
    arcWidth=arc_width,
    nodeColor=node_colors,
    arcColor=arc_color_values,
    arcLabel=arc_label,
    cmapNode=plt.get_cmap("coolwarm"),
    cmapArc=plt.get_cmap("Blues")
)

# %%
df_imp.head()
# Out:
#          AGE     SEX   PTAU181        NFL        GFAP        AB40       AB42  \
# 0  58.929500  Female  2.167700  11.135018  153.128545  109.304989   6.956860
# 1  57.464750    Male  0.951074  12.241553  105.655261  113.991180   5.197182
# 2  62.464066    Male  0.944169  17.346210   69.483929  100.077280   6.615191
# 3  81.475702  Female  3.123887  38.966101   93.721259  144.314806  11.023838
# 4  85.483915  Female  3.308229  47.927891  180.980266  129.650860   8.041534
#
#    MINI MENTAL STATE EXAMINATION  STARKSTEIN SCORE BASELINE CDR  ...  \
# 0                           29.0              17.0          0.5  ...
# 1                           28.0               7.0          0.5  ...
# 2                           29.0              15.0          0.5  ...
# 3                           24.0               9.0            0  ...
# 4                           27.0              14.0          0.5  ...
#
#   BIOMARKER SCORE 2 HIPPOCAMPUS/INTRACRANIAL VOLUME  \
# 0         -0.295161                        0.296111
# 1         -0.516713                        0.284456
# 2          0.197913                        0.232088
# 3         -0.027096                        0.261467
# 4          0.442229                        0.271217
#
#    BRAIN/INTRACRANIAL VOLUME  CEREBRAL BLOOD FLOW  \
# 0                  82.956121              55.5574
# 1                  85.009808              50.0680
# 2                  75.070512              56.1078
# 3                  74.981904              55.5076
# 4                  75.197876              71.3985
#
#    ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY  OUTCOME_MACE  \
# 0                                              No    Unobserved
# 1                                              No            No
# 2                                             Yes    Unobserved
# 3                                             Yes    Unobserved
# 4                                              No    Unobserved
#
#    OUTCOME_CDR_INCREASE DROPOUT REASON VASCULAR RISK SCORE  \
# 0            Unobserved          Other                 3.6
# 1                    No     No dropout                 6.1
# 2            Unobserved        Refusal                 6.2
# 3            Unobserved        Refusal                27.0
# 4            Unobserved       Deceased                19.6
#
#                    PATIENT GROUP
# 0  Vascular cognitive impairment
# 1  Vascular cognitive impairment
# 2                  Heart failure
# 3                  Heart failure
# 4                  Heart failure
#
# [5 rows x 23 columns]

# %%
# Plot with MI-based edge widths
gnb.showInference(
    bn_joint,
    arcWidth=arc_width,
    nodeColor=node_colors,
    arcColor=arc_color_values,
    cmapNode=plt.get_cmap("coolwarm"),
    cmapArc=plt.get_cmap("Blues")
)

# %% [markdown]
# Here, the whole network is considered

# %%
gnb.sideBySide(
  "<H3>OUTCOME CDR INCREASE</H3>",
  "<H3>OUTCOME MACE</H3>",
  bn_joint.cpt("OUTCOME_CDR_INCREASE"),
  bn_joint.cpt("OUTCOME_MACE"),
  ncols=2,
)
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><H3>OUTCOME CDR INCREASE</H3></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><H3>OUTCOME MACE</H3></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='2'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>OUTCOME_CDR_INCREASE</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>BASELINE CDR</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PATIENT GROUP</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Unobserved</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Carotid occlusive disease</center></th><td style='color:black;background-color:#c6b764;text-align:right;padding: 3px;'>0.4444</td><td style='color:black;background-color:#d6a764;text-align:right;padding: 3px;'>0.3194</td><td style='color:black;background-color:#e09d64;text-align:right;padding: 3px;'>0.2361</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Heart failure</center></th><td style='color:black;background-color:#e29b64;text-align:right;padding: 3px;'>0.2263</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.5985</td><td style='color:black;background-color:#e89564;text-align:right;padding: 3px;'>0.1752</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Reference</center></th><td style='color:black;background-color:#aad364;text-align:right;padding: 3px;'>0.6587</td><td style='color:black;background-color:#daa364;text-align:right;padding: 3px;'>0.2857</td><td style='color:black;background-color:#f78664;text-align:right;padding: 3px;'>0.0556</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Vascular cognitive impairment</center></th><td style='color:black;background-color:#e49964;text-align:right;padding: 3px;'>0.2075</td><td style='color:black;background-color:#df9e64;text-align:right;padding: 3px;'>0.2453</td><td style='color:black;background-color:#b8c564;text-align:right;padding: 3px;'>0.5472</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>0.5</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Carotid occlusive disease</center></th><td style='color:black;background-color:#daa364;text-align:right;padding: 3px;'>0.2857</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.5952</td><td style='color:black;background-color:#ef8e64;text-align:right;padding: 3px;'>0.1190</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Heart failure</center></th><td style='color:black;background-color:#f28b64;text-align:right;padding: 3px;'>0.1000</td><td style='color:black;background-color:#9ce164;text-align:right;padding: 3px;'>0.7667</td><td style='color:black;background-color:#ed9064;text-align:right;padding: 3px;'>0.1333</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Reference</center></th><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.3333</td><td style='color:black;background-color:#c6b764;text-align:right;padding: 3px;'>0.4444</td><td style='color:black;background-color:#e29b64;text-align:right;padding: 3px;'>0.2222</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Vascular cognitive impairment</center></th><td style='color:black;background-color:#dda064;text-align:right;padding: 3px;'>0.2609</td><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.5000</td><td style='color:black;background-color:#e09d64;text-align:right;padding: 3px;'>0.2391</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Carotid occlusive disease</center></th><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.5000</td><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.2500</td><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.2500</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Heart failure</center></th><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.2500</td><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.5000</td><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.2500</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Reference</center></th><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.3333</td><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.3333</td><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.3333</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Vascular cognitive impairment</center></th><td style='color:black;background-color:#fa8364;text-align:right;padding: 3px;'>0.0333</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.6000</td><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.3667</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='2'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>OUTCOME_MACE</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>MINI MENTAL STATE EXAMINATION</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PATIENT GROUP</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Unobserved</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>(15;27[</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Carotid occlusive disease</center></th><td style='color:black;background-color:#dca164;text-align:right;padding: 3px;'>0.2692</td><td style='color:black;background-color:#bac364;text-align:right;padding: 3px;'>0.5385</td><td style='color:black;back

# %% [markdown]
# ### 6.3 Uncorrected mutual information — CDR_INCREASE

# %%
# Initialize inference engine
ie = gum.LazyPropagation(bn_joint)

# Get all variables in the network except the outcome
all_variables = bn_joint.names()
variables_to_test = [var for var in all_variables if var != 'OUTCOME_CDR_INCREASE']

# Store results
mi_results = {}

for var in variables_to_test:
    try:
        it = gum.InformationTheory(ie, 'OUTCOME_CDR_INCREASE', [var])
        mi = it.mutualInformationXY()  # Without correction
        mi_results[var] = mi
        print(f'Mutual Information ({var} -> OUTCOME_CDR_INCREASE): {mi:.6f}')
    except Exception as e:
        print(f'Error processing variable {var}: {e}')

# Optional: sort results
sorted_mi = sorted(mi_results.items(), key=lambda x: x[1], reverse=True)

print("\nVariable Importance Ranking for OUTCOME_CDR_INCREASE (Raw Mutual Information)")
for var, score in sorted_mi:
    print(f'{var}: {score:.6f}')
# Out:
# Mutual Information (SMALL VESSEL DISEASE SCORE -> OUTCOME_CDR_INCREASE): 0.005868
# Mutual Information (AGE -> OUTCOME_CDR_INCREASE): 0.000273
# Mutual Information (HIPPOCAMPUS/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE): 0.000030
# Mutual Information (BASELINE CDR -> OUTCOME_CDR_INCREASE): 0.037410
# Mutual Information (OUTCOME_MACE -> OUTCOME_CDR_INCREASE): 0.010276
# Mutual Information (ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY -> OUTCOME_CDR_INCREASE): 0.006376
# Mutual Information (MINI MENTAL STATE EXAMINATION -> OUTCOME_CDR_INCREASE): 0.005776
# Mutual Information (BRAIN/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE): 0.000107
# Mutual Information (STROKE HISTORY -> OUTCOME_CDR_INCREASE): 0.003098
# Mutual Information (VASCULAR RISK SCORE -> OUTCOME_CDR_INCREASE): 0.000809
# Mutual Information (STARKSTEIN SCORE -> OUTCOME_CDR_INCREASE): 0.001927
# Mutual Information (SEX -> OUTCOME_CDR_INCREASE): 0.000646
# Mutual Information (PATIENT GROUP -> OUTCOME_CDR_INCREASE): 0.126680
# Error processing variable DROPOUT REASON: [pyAgrum] Undefined element: The variable DROPOUT REASON(12) does not belong to this optimized inference.
#
# Variable Importance Ranking for OUTCOME_CDR_INCREASE (Raw Mutual Information)
# PATIENT GROUP: 0.126680
# BASELINE CDR: 0.037410
# OUTCOME_MACE: 0.010276
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.006376
# SMALL VESSEL DISEASE SCORE: 0.005868
# MINI MENTAL STATE EXAMINATION: 0.005776
# STROKE HISTORY: 0.003098
# STARKSTEIN SCORE: 0.001927
# VASCULAR RISK SCORE: 0.000809
# SEX: 0.000646
# AGE: 0.000273
# BRAIN/INTRACRANIAL VOLUME: 0.000107
# HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.000030

# %% [markdown]
# ### 6.4 Corrected mutual information — CDR_INCREASE

# %%
# Initialize inference engine
ie = gum.LazyPropagation(bn_joint)

# Get the parents of OUTCOME_CDR_INCREASE
parents = bn_joint.parents(bn_joint.idFromName('OUTCOME_CDR_INCREASE'))
parent_names = [bn_joint.variable(p).name() for p in parents]

# Get all variables in the network except OUTCOME_CDR_INCREASE and its parents
all_variables = bn_joint.names()
variables_to_test = [var for var in all_variables if var != 'OUTCOME_CDR_INCREASE' and var not in parent_names]

# Initialize dictionary to store results
cmi_results = {}

# Loop through each variable and compute conditional mutual information
for var in variables_to_test:
    try:
        it = gum.InformationTheory(ie, 'OUTCOME_CDR_INCREASE', [var], parent_names)
        cmi = it.mutualInformationXYgivenZ()
        cmi_results[var] = cmi
        print(f'Corrected MI ({var} -> OUTCOME_CDR_INCREASE | {parent_names}): {cmi:.6f}')
    except Exception as e:
        print(f'Error processing variable {var}: {e}')

# Optional: sort and display ranking
sorted_cmi = sorted(cmi_results.items(), key=lambda x: x[1], reverse=True)

print("\nVariable Importance Ranking for OUTCOME_CDR_INCREASE (Corrected Mutual Information)")
for var, score in sorted_cmi:
    print(f'{var}: {score:.6f}')
# Out:
# Corrected MI (SMALL VESSEL DISEASE SCORE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (AGE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (HIPPOCAMPUS/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (OUTCOME_MACE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (MINI MENTAL STATE EXAMINATION -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (BRAIN/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (STROKE HISTORY -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (VASCULAR RISK SCORE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (STARKSTEIN SCORE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (SEX -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (DROPOUT REASON -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.207766
#
# Variable Importance Ranking for OUTCOME_CDR_INCREASE (Corrected Mutual Information)
# DROPOUT REASON: 0.207766
# SEX: 0.000000
# STARKSTEIN SCORE: 0.000000
# STROKE HISTORY: 0.000000
# HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.000000
# OUTCOME_MACE: 0.000000
# VASCULAR RISK SCORE: 0.000000
# BRAIN/INTRACRANIAL VOLUME: -0.000000
# AGE: -0.000000
# MINI MENTAL STATE EXAMINATION: -0.000000
# SMALL VESSEL DISEASE SCORE: -0.000000
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: -0.000000

# %% [markdown]
# ### 6.5 Uncorrected mutual information — EVENT_MACE

# %%
# Initialize inference engine
ie = gum.LazyPropagation(bn_joint)

# Get all variables in the network except the outcome
all_variables = bn_joint.names()
variables_to_test = [var for var in all_variables if var != 'OUTCOME_MACE']

# Store results
mi_results = {}

for var in variables_to_test:
    try:
        it = gum.InformationTheory(ie, 'OUTCOME_MACE', [var])
        mi = it.mutualInformationXY()  # Without correction
        mi_results[var] = mi
        print(f'Mutual Information ({var} -> OUTCOME_MACE): {mi:.6f}')
    except Exception as e:
        print(f'Error processing variable {var}: {e}')

# Optional: sort results
sorted_mi = sorted(mi_results.items(), key=lambda x: x[1], reverse=True)

print("\nVariable Importance Ranking for OUTCOME_MACE (Raw Mutual Information)")
for var, score in sorted_mi:
    print(f'{var}: {score:.6f}')
# Out:
# Mutual Information (SMALL VESSEL DISEASE SCORE -> OUTCOME_MACE): 0.001879
# Mutual Information (AGE -> OUTCOME_MACE): 0.000064
# Mutual Information (HIPPOCAMPUS/INTRACRANIAL VOLUME -> OUTCOME_MACE): 0.000007
# Mutual Information (BASELINE CDR -> OUTCOME_MACE): 0.012060
# Mutual Information (ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY -> OUTCOME_MACE): 0.005739
# Mutual Information (MINI MENTAL STATE EXAMINATION -> OUTCOME_MACE): 0.041850
# Mutual Information (BRAIN/INTRACRANIAL VOLUME -> OUTCOME_MACE): 0.000036
# Mutual Information (OUTCOME_CDR_INCREASE -> OUTCOME_MACE): 0.010276
# Mutual Information (STROKE HISTORY -> OUTCOME_MACE): 0.001246
# Mutual Information (VASCULAR RISK SCORE -> OUTCOME_MACE): 0.000303
# Mutual Information (STARKSTEIN SCORE -> OUTCOME_MACE): 0.000719
# Mutual Information (SEX -> OUTCOME_MACE): 0.000527
# Mutual Information (PATIENT GROUP -> OUTCOME_MACE): 0.072459
# Error processing variable DROPOUT REASON: [pyAgrum] Undefined element: The variable DROPOUT REASON(12) does not belong to this optimized inference.
#
# Variable Importance Ranking for OUTCOME_MACE (Raw Mutual Information)
# PATIENT GROUP: 0.072459
# MINI MENTAL STATE EXAMINATION: 0.041850
# BASELINE CDR: 0.012060
# OUTCOME_CDR_INCREASE: 0.010276
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.005739
# SMALL VESSEL DISEASE SCORE: 0.001879
# STROKE HISTORY: 0.001246
# STARKSTEIN SCORE: 0.000719
# SEX: 0.000527
# VASCULAR RISK SCORE: 0.000303
# AGE: 0.000064
# BRAIN/INTRACRANIAL VOLUME: 0.000036
# HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.000007

# %% [markdown]
# ### 6.6 Corrected mutual information — EVENT_MACE

# %%
# Initialize inference engine
ie = gum.LazyPropagation(bn_joint)

# Get the parents of EVENT_MACE
parents = bn_joint.parents(bn_joint.idFromName('OUTCOME_MACE'))
parent_names = [bn_joint.variable(p).name() for p in parents]

# Get all variables in the network except OUTCOME_MACE and its parents
all_variables = bn_joint.names()
variables_to_test = [var for var in all_variables if var != 'OUTCOME_MACE' and var not in parent_names]

# Initialize dictionary to store results
cmi_results = {}

# Loop through each variable and compute conditional mutual information
for var in variables_to_test:
    try:
        it = gum.InformationTheory(ie, 'OUTCOME_MACE', [var], parent_names)
        cmi = it.mutualInformationXYgivenZ()
        cmi_results[var] = cmi
        print(f'Corrected MI ({var} -> OUTCOME_MACE | {parent_names}): {cmi:.6f}')
    except Exception as e:
        print(f'Error processing variable {var}: {e}')

# Optional: sort and display ranking
sorted_cmi = sorted(cmi_results.items(), key=lambda x: x[1], reverse=True)

print("\nVariable Importance Ranking for OUTCOME_MACE (Corrected Mutual Information)")
for var, score in sorted_cmi:
    print(f'{var}: {score:.6f}')
# Out:
# Corrected MI (SMALL VESSEL DISEASE SCORE -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (AGE -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (HIPPOCAMPUS/INTRACRANIAL VOLUME -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (BASELINE CDR -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): -0.000000
# Corrected MI (BRAIN/INTRACRANIAL VOLUME -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (OUTCOME_CDR_INCREASE -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (STROKE HISTORY -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (VASCULAR RISK SCORE -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (STARKSTEIN SCORE -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (SEX -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.000000
# Corrected MI (DROPOUT REASON -> OUTCOME_MACE | ['MINI MENTAL STATE EXAMINATION', 'PATIENT GROUP']): 0.244682
#
# Variable Importance Ranking for OUTCOME_MACE (Corrected Mutual Information)
# DROPOUT REASON: 0.244682
# STARKSTEIN SCORE: 0.000000
# BASELINE CDR: 0.000000
# SEX: 0.000000
# VASCULAR RISK SCORE: 0.000000
# BRAIN/INTRACRANIAL VOLUME: 0.000000
# HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.000000
# AGE: 0.000000
# STROKE HISTORY: 0.000000
# OUTCOME_CDR_INCREASE: 0.000000
# SMALL VESSEL DISEASE SCORE: 0.000000
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: -0.000000

# %% [markdown]
# ## 7. Biomarker Layer Ablation
#
# Contrast networks learned with and without the specialised biomarker layer.

# %%
import random
from itertools import product

def build_bn_biomarkers(df, outcomes, layer_map, type_processor, score='K2', use_tabu=True, random_seed=42):
    
    random.seed(random_seed)
    np.random.seed(random_seed)

    # Step 1: Drop excluded outcome variables and excluded biomarkers
    outcomes_all_layers = [v for k, v in layer_map.items() if "Outcomes" in k or "Dropout" in k]
    outcomes_flat = [var for sublist in outcomes_all_layers for var in sublist]
    drop_outcomes = list(set(outcomes_flat) - set(outcomes))

    df_reduced = df.drop(columns=drop_outcomes, errors='ignore')
    variables_to_keep = df_reduced.columns.tolist()

    # Step 2: Build template from reduced dataframe
    template_reduced = type_processor.discretizedTemplate(df_reduced)

    # Step 3: Instantiate the learner
    learner = gum.BNLearner(df_reduced, template_reduced)

    if score.upper() == 'K2':
        learner.useScoreK2()
    elif score.upper() == 'BIC':
        learner.useScoreBIC()
        learner.useSmoothingPrior()
    elif score.upper() == "BDEU":
        learner.useScoreBDeu(ess=1)
    else:
        raise ValueError("Unsupported score method: choose 'K2' or 'BIC'")

    if use_tabu:
        learner.useLocalSearchWithTabuList()
    else:
        learner.useGreedyHillClimbing()

  # Step 4: Build allowed arcs with special handling for dropout layer
    layer_keys = list(layer_map.keys())

    dropout_layer_keys = [k for k in layer_keys if "Dropout" in k]
    dropout_vars = []
    for key in dropout_layer_keys:
        dropout_vars += layer_map[key]

    allowed_arcs = []

    for i in range(len(layer_keys)):
        from_vars = layer_map[layer_keys[i]]
        for j in range(i, len(layer_keys)):
            to_vars = layer_map[layer_keys[j]]

            for parent, child in product(from_vars, to_vars):
                # Special rule: only allow arcs into dropout vars if from outcome
                if child in dropout_vars:
                    if parent in outcomes:
                        allowed_arcs.append((parent, child))
                    continue  # skip all others going into dropout

                if parent in variables_to_keep and child in variables_to_keep:
                    allowed_arcs.append((parent, child))

    # Step 5: Enforce allowed arcs, forbid the rest
    for parent in variables_to_keep:
        for child in variables_to_keep:
            if parent != child and (parent, child) not in allowed_arcs:
                learner.addForbiddenArc(parent, child)

    # Step 6: Disallow arcs between actual outcomes, but allow outcomes → dropout
    true_outcomes = [var for var in outcomes if "DROPOUT" not in var.upper()]
    for parent in true_outcomes:
        for child in true_outcomes:
            if parent != child:
                learner.addForbiddenArc(parent, child)

    learner.setMaxIndegree(5)
    # Step 7: Learn the network
    bn = learner.learnBN()
    return bn

# %%
bn_with_biomarkers = build_bn_biomarkers(df_imp, ["OUTCOME_CDR_INCREASE", "OUTCOME_MACE", "DROPOUT REASON"], layer_map=layer_map, type_processor=type_processor, score="K2")

# %% [markdown]
# ### 7.1 Biomarker-outcome logistic regression
#
# Quantify adjusted associations between each biomarker and the clinical outcomes using logistic regression models with age and sex as covariates.

# %%
import statsmodels.formula.api as smf

biomarker_vars = [
    var for var in layer_map.get('L4 – Potential disease process markers', [])
    if var in df_imp.columns
]
outcome_labels = {
    'OUTCOME_MACE': 'MACE event',
    'OUTCOME_CDR_INCREASE': 'CDR increase'
}

logit_rows = []

for outcome, label in outcome_labels.items():
    observed = df_imp[df_imp[outcome].isin(['Yes', 'No'])].copy()
    if observed.empty:
        continue

    outcome_bin = f"{outcome}_bin"
    observed[outcome_bin] = (observed[outcome] == 'Yes').astype(int)

    for biomarker in biomarker_vars:
        biomarker_term = f'Q("{biomarker}")'
        model_specs = [
            {
                "label": "Unadjusted",
                "required_vars": [outcome_bin, biomarker],
                "formula_suffix": ""
            },
            {
                "label": "Adjusted (age + sex)",
                "required_vars": [outcome_bin, biomarker, 'AGE', 'SEX'],
                "formula_suffix": " + AGE + C(SEX)"
            },
        ]

        for spec in model_specs:
            missing_covars = [col for col in spec["required_vars"] if col not in observed.columns]
            if missing_covars:
                logit_rows.append({
                    'Outcome': label,
                    'Biomarker': biomarker,
                    'Model': spec["label"],
                    'Odds Ratio': np.nan,
                    'CI 2.5%': np.nan,
                    'CI 97.5%': np.nan,
                    'p-value': np.nan,
                    'N': 0,
                    'Notes': f"Missing covariates: {', '.join(missing_covars)}"
                })
                continue

            model_df = observed[spec["required_vars"]].dropna()
            sample_size = int(model_df.shape[0])

            if sample_size == 0:
                logit_rows.append({
                    'Outcome': label,
                    'Biomarker': biomarker,
                    'Model': spec["label"],
                    'Odds Ratio': np.nan,
                    'CI 2.5%': np.nan,
                    'CI 97.5%': np.nan,
                    'p-value': np.nan,
                    'N': sample_size,
                    'Notes': 'No complete cases after filtering'
                })
                continue

            if model_df[outcome_bin].nunique() < 2 or model_df[biomarker].nunique() < 2:
                logit_rows.append({
                    'Outcome': label,
                    'Biomarker': biomarker,
                    'Model': spec["label"],
                    'Odds Ratio': np.nan,
                    'CI 2.5%': np.nan,
                    'CI 97.5%': np.nan,
                    'p-value': np.nan,
                    'N': sample_size,
                    'Notes': 'Insufficient variation'
                })
                continue

            suffix = spec["formula_suffix"]
            formula = f"{outcome_bin} ~ {biomarker_term}{suffix}"

            try:
                fit = smf.logit(formula=formula, data=model_df).fit(disp=0)
            except Exception as exc:
                logit_rows.append({
                    'Outcome': label,
                    'Biomarker': biomarker,
                    'Model': spec["label"],
                    'Odds Ratio': np.nan,
                    'CI 2.5%': np.nan,
                    'CI 97.5%': np.nan,
                    'p-value': np.nan,
                    'N': sample_size,
                    'Notes': f'Fit failed: {exc}'
                })
                continue

            param_name = biomarker_term

            if param_name not in fit.params.index:
                logit_rows.append({
                    'Outcome': label,
                    'Biomarker': biomarker,
                    'Model': spec["label"],
                    'Odds Ratio': np.nan,
                    'CI 2.5%': np.nan,
                    'CI 97.5%': np.nan,
                    'p-value': np.nan,
                    'N': sample_size,
                    'Notes': 'Biomarker term dropped during fitting'
                })
                continue

            conf = fit.conf_int().loc[param_name]
            logit_rows.append({
                'Outcome': label,
                'Biomarker': biomarker,
                'Model': spec["label"],
                'Odds Ratio': np.exp(fit.params[param_name]),
                'CI 2.5%': np.exp(conf[0]),
                'CI 97.5%': np.exp(conf[1]),
                'p-value': fit.pvalues[param_name],
                'N': sample_size,
                'Notes': ''
            })

logit_results = pd.DataFrame(logit_rows)

if not logit_results.empty:
    display_order = ['Unadjusted', 'Adjusted (age + sex)']
    formatted = logit_results.copy()
    formatted['Model'] = pd.Categorical(formatted['Model'], categories=display_order, ordered=True)
    formatted['Odds Ratio (95% CI)'] = formatted.apply(
        lambda row: (
            f"{row['Odds Ratio']:.2f} ({row['CI 2.5%']:.2f}, {row['CI 97.5%']:.2f})"
            if pd.notnull(row['Odds Ratio']) else 'NA'
        ),
        axis=1
    )
    formatted['p-value'] = formatted['p-value'].map(
        lambda x: f"{x:.3g}" if pd.notnull(x) else 'NA'
    )
    formatted = formatted.sort_values(['Outcome', 'Biomarker', 'Model']).reset_index(drop=True)

    wide = (
        formatted
        .pivot_table(
            index=['Outcome', 'Biomarker', 'N'],
            columns='Model',
            values=['Odds Ratio (95% CI)', 'p-value'],
            aggfunc='first'
        )
        .sort_index()
    )

    wide.columns = [f"{metric} ({model})" for metric, model in wide.columns]
    wide = wide.reset_index()
    display(wide[['Outcome', 'Biomarker', 'N'] + [col for col in wide.columns if col not in {'Outcome', 'Biomarker', 'N'}]])
else:
    display(pd.DataFrame({'Message': ['No logistic regression models were fitted.']}))
# Out:
# /var/folders/k7/m876w0ts2n77lwt3x1dc25zc0000gp/T/ipykernel_4189/1656990172.py:152: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   .pivot_table(
#          Outcome            Biomarker    N Odds Ratio (95% CI) (Unadjusted)  \
# 0   CDR increase                 AB40  304                1.01 (1.00, 1.03)
# 1   CDR increase                 AB42  304                1.09 (0.96, 1.24)
# 2   CDR increase    BIOMARKER SCORE 1  304                2.58 (1.71, 3.90)
# 3   CDR increase    BIOMARKER SCORE 2  304                1.84 (1.36, 2.51)
# 4   CDR increase  CEREBRAL BLOOD FLOW  304                0.98 (0.96, 1.00)
# 5   CDR increase                 GFAP  304                1.01 (1.01, 1.02)
# 6   CDR increase                  NFL  304                1.01 (1.00, 1.03)
# 7   CDR increase              PTAU181  304                1.53 (1.19, 1.98)
# 8     MACE event                 AB40  328                1.00 (0.99, 1.01)
# 9     MACE event                 AB42  328                0.92 (0.82, 1.04)
# 10    MACE event    BIOMARKER SCORE 1  328                1.68 (1.20, 2.35)
# 11    MACE event    BIOMARKER SCORE 2  328                1.68 (1.29, 2.21)
# 12    MACE event  CEREBRAL BLOOD FLOW  328                0.98 (0.96, 1.00)
# 13    MACE event                 GFAP  328                1.00 (1.00, 1.01)
# 14    MACE event                  NFL  328                1.02 (1.00, 1.04)
# 15    MACE event              PTAU181  328                1.02 (0.83, 1.27)
#
#    Odds Ratio (95% CI) (Adjusted (age + sex)) p-value (Unadjusted)  \
# 0                           1.01 (1.00, 1.02)               0.0196
# 1                           1.07 (0.94, 1.22)                0.184
# 2                           2.35 (1.55, 3.56)             6.05e-06
# 3                           1.76 (1.27, 2.43)             9.67e-05
# 4                           0.99 (0.97, 1.01)                0.108
# 5                           1.01 (1.00, 1.01)             4.36e-05
# 6                           1.01 (1.00, 1.02)                0.072
# 7                           1.37 (1.06, 1.77)              0.00109
# 8                           0.99 (0.98, 1.00)                0.991
# 9                           0.90 (0.80, 1.02)                0.167
# 10                          1.48 (1.03, 2.11)              0.00276
# 11                          1.47 (1.11, 1.95)             0.000156
# 12                          0.99 (0.97, 1.01)               0.0208
# 13                          1.00 (1.00, 1.01)               0.0315
# 14                          1.01 (0.99, 1.02)               0.0125
# 15                          0.83 (0.65, 1.06)                0.837
#
#    p-value (Adjusted (age + sex))
# 0                           0.139
# 1                           0.284
# 2                        6.16e-05
# 3                        0.000673
# 4                           0.325
# 5                         0.00452
# 6                           0.235
# 7                          0.0173
# 8                           0.174
# 9                          0.0965
# 10                         0.0318
# 11                         0.0077
# 12                          0.343
# 13                          0.746
# 14                          0.259
# 15                          0.143

# %% [markdown]
# #### Biomarker distribution checks
#
# Visualise biomarker levels by CDR outcome status to verify the magnitude of group differences suggested by the logistic regression.

# %%
# Create inference engine
ie = gum.LazyPropagation(bn_with_biomarkers)
ie.makeInference()

# Compute MI and apply it to arcs using variable indices (not names)
arc_width = {}

for u, v in bn_with_biomarkers.arcs():  # u and v are variable IDs
    try:
        it = gum.InformationTheory(ie, v, [u])  # use IDs directly
        mi = it.mutualInformationXY()
    except:
        mi = 0.1

    arc_width[(u, v)] = mi  # ✅ use indices, not names

max_mi = max(arc_width.values())
arc_width = {k: (np.sqrt(v) / np.sqrt(max_mi) * 3.0 + 0.5) for k, v in arc_width.items()}

# %%
var_name_to_id = {bn_with_biomarkers.variable(i).name(): i for i in range(bn_with_biomarkers.size())}

bootstrap_freq_id = {}

for (parent_name, child_name), freq in edge_freqs.items():
    try:
        parent_id = var_name_to_id[parent_name]
        child_id = var_name_to_id[child_name]
        bootstrap_freq_id[(parent_id, child_id)] = freq
    except KeyError:
        continue  # skip if variable not found in network

# %%
# Update layer_order for color mapping and arc logic
layer_order = [
    'L0 – Unmodifiable demographics',
    'L1 – Modifiable demograhpics / Lifestyle factors',
    'L2 – Cardiovascular risk factors',
    'L3 – Specialized biomarkers',  # <-- NEW LAYER
    'L4 – Potential disease process markers',
    'L5 - Imaging markers of neurovascular damage',
    'L6 – Current and previous cardiovascular diagnoses / Vascular interventions',
    'L7 - Functional status',
    'L8 – Outcomes',
    'L9 – Dropout'
]

# %%
# Set adjusted min and max color values
min_color_val = 0.111111
max_color_val = 0.99999
steps = len(layer_order) - 1

# Create adjusted color intensity map
layer_color_map = {
    name: min_color_val + i * (max_color_val - min_color_val) / steps
    for i, name in enumerate(layer_order)
}

# Build the nodeColor dictionary
node_colors = {}
for layer_name, variables in layer_map.items():
    color_val = layer_color_map.get(layer_name, 0.5)  # fallback if unknown
    for var in variables:
        if var in bn_with_biomarkers.names():
            node_colors[var] = color_val

# %%
from collections import defaultdict
def bootstrap_edge_frequencies(df, outcomes, layer_map, type_processor,
                                build_bn_func, n_bootstraps=100, score='K2', use_tabu=True, random_seed=42):
    edge_counts = defaultdict(int)

    for i in range(n_bootstraps):
        seed = random_seed + i
        random.seed(seed)
        np.random.seed(seed)

        # Bootstrap resample
        boot_df = df.sample(frac=1.0, replace=True, random_state=seed)

        try:
            bn = build_bn_func(boot_df, outcomes, layer_map, type_processor,
                               score=score, use_tabu=use_tabu, random_seed=seed)
        except Exception as e:
            print(f"Bootstrap {i} failed: {e}")
            continue

        # Count arcs
        for parent_id, child_id in bn.arcs():
            parent = bn.variable(parent_id).name()
            child = bn.variable(child_id).name()
            edge_counts[(parent, child)] += 1

    # Normalize to frequencies
    edge_frequencies = {edge: count / n_bootstraps for edge, count in edge_counts.items()}
    return edge_frequencies

# %%
# Met biomarkers
edge_freqs_with = bootstrap_edge_frequencies(
    df=df_imp,
    outcomes=["OUTCOME_CDR_INCREASE", "OUTCOME_MACE", "DROPOUT REASON"],
    layer_map=layer_map,
    type_processor=type_processor,
    build_bn_func=build_bn_biomarkers,
    n_bootstraps=10,
    score='K2',
    use_tabu=True

)

# Print top edges
for edge, freq in sorted(edge_freqs_with.items(), key=lambda x: -x[1]):
    print(f"{edge[0]} → {edge[1]}: {freq:.2f}")
# Out:
# PATIENT GROUP → OUTCOME_CDR_INCREASE: 1.00
# SEX → VASCULAR RISK SCORE: 1.00
# BASELINE CDR → MINI MENTAL STATE EXAMINATION: 1.00
# OUTCOME_CDR_INCREASE → DROPOUT REASON: 1.00
# PATIENT GROUP → BASELINE CDR: 1.00
# AGE → GFAP: 1.00
# SMALL VESSEL DISEASE SCORE → PATIENT GROUP: 1.00
# OUTCOME_MACE → DROPOUT REASON: 1.00
# AGE → VASCULAR RISK SCORE: 1.00
# GFAP → PTAU181: 0.90
# GFAP → BRAIN/INTRACRANIAL VOLUME: 0.90
# VASCULAR RISK SCORE → BRAIN/INTRACRANIAL VOLUME: 0.90
# AGE → NFL: 0.90
# VASCULAR RISK SCORE → CEREBRAL BLOOD FLOW: 0.80
# BRAIN/INTRACRANIAL VOLUME → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.80
# NFL → AB42: 0.80
# BASELINE CDR → OUTCOME_CDR_INCREASE: 0.80
# AGE → CEREBRAL BLOOD FLOW: 0.80
# SEX → CEREBRAL BLOOD FLOW: 0.80
# PTAU181 → BRAIN/INTRACRANIAL VOLUME: 0.80
# NFL → PTAU181: 0.80
# SEX → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.70
# SEX → NFL: 0.70
# NFL → AB40: 0.70
# PATIENT GROUP → STARKSTEIN SCORE: 0.70
# VASCULAR RISK SCORE → NFL: 0.70
# VASCULAR RISK SCORE → BIOMARKER SCORE 1: 0.70
# GFAP → AB40: 0.70
# AB42 → CEREBRAL BLOOD FLOW: 0.70
# VASCULAR RISK SCORE → MINI MENTAL STATE EXAMINATION: 0.70
# BASELINE CDR → STARKSTEIN SCORE: 0.70
# AGE → AB40: 0.70
# VASCULAR RISK SCORE → SMALL VESSEL DISEASE SCORE: 0.70
# NFL → BIOMARKER SCORE 2: 0.60
# AGE → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.60
# AB40 → BIOMARKER SCORE 1: 0.60
# BIOMARKER SCORE 1 → BIOMARKER SCORE 2: 0.60
# BIOMARKER SCORE 1 → PATIENT GROUP: 0.60
# PATIENT GROUP → OUTCOME_MACE: 0.60
# AGE → AB42: 0.60
# AGE → BRAIN/INTRACRANIAL VOLUME: 0.60
# GFAP → BIOMARKER SCORE 1: 0.60
# SMALL VESSEL DISEASE SCORE → STARKSTEIN SCORE: 0.60
# AB42 → AB40: 0.60
# PATIENT GROUP → STROKE HISTORY: 0.60
# NFL → CEREBRAL BLOOD FLOW: 0.60
# MINI MENTAL STATE EXAMINATION → OUTCOME_MACE: 0.60
# SMALL VESSEL DISEASE SCORE → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.50
# HIPPOCAMPUS/INTRACRANIAL VOLUME → STARKSTEIN SCORE: 0.50
# CEREBRAL BLOOD FLOW → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.50
# NFL → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.50
# AGE → OUTCOME_MACE: 0.50
# CEREBRAL BLOOD FLOW → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.50
# AB40 → BIOMARKER SCORE 2: 0.50
# VASCULAR RISK SCORE → AB42: 0.50
# SEX → GFAP: 0.50
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → PATIENT GROUP: 0.50
# GFAP → NFL: 0.50
# AGE → BIOMARKER SCORE 1: 0.50
# PATIENT GROUP → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.50
# NFL → BIOMARKER SCORE 1: 0.50
# AB40 → PTAU181: 0.50
# NFL → GFAP: 0.50
# BIOMARKER SCORE 2 → PATIENT GROUP: 0.50
# AGE → PTAU181: 0.50
# HIPPOCAMPUS/INTRACRANIAL VOLUME → OUTCOME_MACE: 0.50
# PTAU181 → BIOMARKER SCORE 2: 0.50
# VASCULAR RISK SCORE → PTAU181: 0.50
# VASCULAR RISK SCORE → BIOMARKER SCORE 2: 0.50
# BIOMARKER SCORE 2 → STARKSTEIN SCORE: 0.40
# STROKE HISTORY → PATIENT GROUP: 0.40
# GFAP → AB42: 0.40
# BIOMARKER SCORE 2 → PTAU181: 0.40
# NFL → OUTCOME_MACE: 0.40
# SEX → BIOMARKER SCORE 2: 0.40
# SMALL VESSEL DISEASE SCORE → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.40
# VASCULAR RISK SCORE → AB40: 0.40
# GFAP → CEREBRAL BLOOD FLOW: 0.40
# PTAU181 → AB40: 0.40
# VASCULAR RISK SCORE → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.40
# GFAP → BIOMARKER SCORE 2: 0.40
# AB40 → STARKSTEIN SCORE: 0.40
# PTAU181 → BIOMARKER SCORE 1: 0.40
# BIOMARKER SCORE 2 → BIOMARKER SCORE 1: 0.40
# BRAIN/INTRACRANIAL VOLUME → OUTCOME_MACE: 0.40
# BIOMARKER SCORE 1 → BRAIN/INTRACRANIAL VOLUME: 0.40
# AB40 → AB42: 0.40
# SEX → BIOMARKER SCORE 1: 0.40
# GFAP → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.40
# SMALL VESSEL DISEASE SCORE → MINI MENTAL STATE EXAMINATION: 0.30
# CEREBRAL BLOOD FLOW → BRAIN/INTRACRANIAL VOLUME: 0.30
# SEX → AB40: 0.30
# CEREBRAL BLOOD FLOW → MINI MENTAL STATE EXAMINATION: 0.30
# MINI MENTAL STATE EXAMINATION → STARKSTEIN SCORE: 0.30
# NFL → STARKSTEIN SCORE: 0.30
# STROKE HISTORY → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.30
# AB42 → BRAIN/INTRACRANIAL VOLUME: 0.30
# AGE → STARKSTEIN SCORE: 0.30
# AB42 → PTAU181: 0.30
# AGE → OUTCOME_CDR_INCREASE: 0.30
# GFAP → OUTCOME_CDR_INCREASE: 0.30
# AB40 → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.30
# STROKE HISTORY → OUTCOME_CDR_INCREASE: 0.30
# MINI MENTAL STATE EXAMINATION → OUTCOME_CDR_INCREASE: 0.30
# NFL → BRAIN/INTRACRANIAL VOLUME: 0.30
# CEREBRAL BLOOD FLOW → STARKSTEIN SCORE: 0.30
# AB40 → CEREBRAL BLOOD FLOW: 0.30
# GFAP → OUTCOME_MACE: 0.30
# PTAU181 → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.30
# BIOMARKER SCORE 2 → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.30
# BRAIN/INTRACRANIAL VOLUME → OUTCOME_CDR_INCREASE: 0.30
# SEX → AGE: 0.30
# VASCULAR RISK SCORE → OUTCOME_MACE: 0.20
# CEREBRAL BLOOD FLOW → BIOMARKER SCORE 1: 0.20
# SMALL VESSEL DISEASE SCORE → OUTCOME_MACE: 0.20
# NFL → SMALL VESSEL DISEASE SCORE: 0.20
# CEREBRAL BLOOD FLOW → PTAU181: 0.20
# VASCULAR RISK SCORE → OUTCOME_CDR_INCREASE: 0.20
# SEX → AB42: 0.20
# AB40 → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.20
# CEREBRAL BLOOD FLOW → AB42: 0.20
# PATIENT GROUP → MINI MENTAL STATE EXAMINATION: 0.20
# BIOMARKER SCORE 1 → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.20
# SEX → PATIENT GROUP: 0.20
# NFL → MINI MENTAL STATE EXAMINATION: 0.20
# SEX → PTAU181: 0.20
# PTAU181 → OUTCOME_CDR_INCREASE: 0.20
# BASELINE CDR → OUTCOME_MACE: 0.20
# AB40 → PATIENT GROUP: 0.20
# AGE → SMALL VESSEL DISEASE SCORE: 0.20
# SEX → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.20
# BIOMARKER SCORE 2 → CEREBRAL BLOOD FLOW: 0.20
# CEREBRAL BLOOD FLOW → OUTCOME_MACE: 0.20
# STROKE HISTORY → MINI MENTAL STATE EXAMINATION: 0.20
# BIOMARKER SCORE 1 → OUTCOME_MACE: 0.20
# BIOMARKER SCORE 1 → CEREBRAL BLOOD FLOW: 0.20
# PTAU181 → MINI MENTAL STATE EXAMINATION: 0.20
# BIOMARKER SCORE 1 → SMALL VESSEL DISEASE SCORE: 0.20
# VASCULAR RISK SCORE → PATIENT GROUP: 0.20
# STROKE HISTORY → BASELINE CDR: 0.20
# CEREBRAL BLOOD FLOW → PATIENT GROUP: 0.20
# BIOMARKER SCORE 1 → PTAU181: 0.20
# HIPPOCAMPUS/INTRACRANIAL VOLUME → SMALL VESSEL DISEASE SCORE: 0.20
# BIOMARKER SCORE 1 → HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.20
# BIOMARKER SCORE 2 → NFL: 0.20
# PTAU181 → AB42: 0.20
# AGE → BIOMARKER SCORE 2: 0.20
# SMALL VESSEL DISEASE SCORE → BRAIN/INTRACRANIAL VOLUME: 0.20
# SEX → OUTCOME_CDR_INCREASE: 0.20
# AB42 → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.20
# GFAP → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.20
# HIPPOCAMPUS/INTRACRANIAL VOLUME → BRAIN/INTRACRANIAL VOLUME: 0.20
# VASCULAR RISK SCORE → GFAP: 0.20
# STARKSTEIN SCORE → MINI MENTAL STATE EXAMINATION: 0.20
# PTAU181 → OUTCOME_MACE: 0.20
# BIOMARKER SCORE 2 → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.10
# CEREBRAL BLOOD FLOW → BIOMARKER SCORE 2: 0.10
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → OUTCOME_CDR_INCREASE: 0.10
# SEX → STARKSTEIN SCORE: 0.10
# NFL → OUTCOME_CDR_INCREASE: 0.10
# AB40 → OUTCOME_MACE: 0.10
# AB42 → OUTCOME_CDR_INCREASE: 0.10
# AB40 → MINI MENTAL STATE EXAMINATION: 0.10
# HIPPOCAMPUS/INTRACRANIAL VOLUME → OUTCOME_CDR_INCREASE: 0.10
# BRAIN/INTRACRANIAL VOLUME → STARKSTEIN SCORE: 0.10
# GFAP → SMALL VESSEL DISEASE SCORE: 0.10
# SEX → MINI MENTAL STATE EXAMINATION: 0.10
# AB42 → NFL: 0.10
# AB42 → BIOMARKER SCORE 2: 0.10
# PTAU181 → PATIENT GROUP: 0.10
# AB42 → PATIENT GROUP: 0.10
# SEX → OUTCOME_MACE: 0.10
# HIPPOCAMPUS/INTRACRANIAL VOLUME → MINI MENTAL STATE EXAMINATION: 0.10
# STARKSTEIN SCORE → OUTCOME_MACE: 0.10
# BIOMARKER SCORE 1 → AB42: 0.10
# BRAIN/INTRACRANIAL VOLUME → PATIENT GROUP: 0.10
# BIOMARKER SCORE 1 → OUTCOME_CDR_INCREASE: 0.10
# BIOMARKER SCORE 2 → AB40: 0.10
# BIOMARKER SCORE 1 → AB40: 0.10
# AGE → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.10
# PTAU181 → GFAP: 0.10
# BIOMARKER SCORE 2 → OUTCOME_MACE: 0.10
# PTAU181 → CEREBRAL BLOOD FLOW: 0.10
# VASCULAR RISK SCORE → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.10
# PTAU181 → NFL: 0.10
# BRAIN/INTRACRANIAL VOLUME → BASELINE CDR: 0.10
# AB40 → OUTCOME_CDR_INCREASE: 0.10
# GFAP → STARKSTEIN SCORE: 0.10
# GFAP → PATIENT GROUP: 0.10
# CEREBRAL BLOOD FLOW → AB40: 0.10
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → MINI MENTAL STATE EXAMINATION: 0.10
# BRAIN/INTRACRANIAL VOLUME → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.10
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY → STARKSTEIN SCORE: 0.10
# SMALL VESSEL DISEASE SCORE → STROKE HISTORY: 0.10
# SMALL VESSEL DISEASE SCORE → OUTCOME_CDR_INCREASE: 0.10
# SEX → BRAIN/INTRACRANIAL VOLUME: 0.10
# NFL → ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.10
# PTAU181 → STARKSTEIN SCORE: 0.10

# %%
# Create inference engine
ie = gum.LazyPropagation(bn_with_biomarkers)
ie.makeInference()

# Compute MI and apply it to arcs using variable indices (not names)
arc_width = {}

for u, v in bn_with_biomarkers.arcs():  # u and v are variable IDs
    try:
        it = gum.InformationTheory(ie, v, [u])  # use IDs directly
        mi = it.mutualInformationXY()
    except:
        mi = 0.1

    arc_width[(u, v)] = mi  # ✅ use indices, not names

max_mi = max(arc_width.values())
arc_width = {k: (np.sqrt(v) / np.sqrt(max_mi) * 3.0 + 0.5) for k, v in arc_width.items()}

# %%
# Use edge_freqs_with for the network with biomarkers!
var_name_to_id = {bn_with_biomarkers.variable(i).name(): i for i in range(bn_with_biomarkers.size())}

bootstrap_freq_id = {}

for (parent_name, child_name), freq in edge_freqs_with.items():  # <-- use edge_freqs_with here!
    try:
        parent_id = var_name_to_id[parent_name]
        child_id = var_name_to_id[child_name]
        bootstrap_freq_id[(parent_id, child_id)] = freq
    except KeyError:
        continue  # skip if variable not found in network

arc_color_values = {
    arc: bootstrap_freq_id.get(arc, 0.0)
    for arc in bn_with_biomarkers.arcs()
}

# %%
# Plot with MI-based edge widths
gnb.showInference(
    bn_with_biomarkers,
    arcWidth=arc_width,
    nodeColor=node_colors,
    arcColor=arc_color_values,
    cmapArc=plt.get_cmap("Blues"),
    cmapNode=plt.get_cmap("coolwarm")
    )

# %%
arc_label = {
    arc: f"f={int(bootstrap_freq_id.get(arc, 0.0) * 100)}%"
    for arc in bn_with_biomarkers.arcs()
}

# %%
# Plot with MI-based edge widths
gnb.showBN(
    bn_with_biomarkers,
    arcWidth=arc_width,
    nodeColor=node_colors,
    arcColor=arc_color_values,
    arcLabel=arc_label,
    cmapNode=plt.get_cmap("coolwarm"),
    cmapArc=plt.get_cmap("Blues")
)

# %% [markdown]
# The specialised biomarkers appear upstream but are not directly connected to the outcomes; removing the layer leaves predictive behaviour largely unchanged.

# %%
gnb.showTensor(bn_with_biomarkers.cpt(bn_with_biomarkers.idFromName("OUTCOME_CDR_INCREASE")), digits=2)
# Out:
# <table style="border:1px solid black;border-collapse: collapse;"><tr><th colspan='2'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>OUTCOME_CDR_INCREASE</center>
#       </th></tr><tr><th style='border:1px solid black;color:black;background-color:#808080'><center>BASELINE CDR</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>PATIENT GROUP</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Unobserved</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Carotid occlusive disease</center></th><td style='color:black;background-color:#c6b764;text-align:right;padding: 3px;'>0.44</td><td style='color:black;background-color:#d6a764;text-align:right;padding: 3px;'>0.32</td><td style='color:black;background-color:#e09d64;text-align:right;padding: 3px;'>0.24</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Heart failure</center></th><td style='color:black;background-color:#e29b64;text-align:right;padding: 3px;'>0.23</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.60</td><td style='color:black;background-color:#e89564;text-align:right;padding: 3px;'>0.18</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Reference</center></th><td style='color:black;background-color:#aad364;text-align:right;padding: 3px;'>0.66</td><td style='color:black;background-color:#daa364;text-align:right;padding: 3px;'>0.29</td><td style='color:black;background-color:#f78664;text-align:right;padding: 3px;'>0.06</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Vascular cognitive impairment</center></th><td style='color:black;background-color:#e49964;text-align:right;padding: 3px;'>0.21</td><td style='color:black;background-color:#df9e64;text-align:right;padding: 3px;'>0.25</td><td style='color:black;background-color:#b8c564;text-align:right;padding: 3px;'>0.55</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>0.5</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Carotid occlusive disease</center></th><td style='color:black;background-color:#daa364;text-align:right;padding: 3px;'>0.29</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.60</td><td style='color:black;background-color:#ef8e64;text-align:right;padding: 3px;'>0.12</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Heart failure</center></th><td style='color:black;background-color:#f28b64;text-align:right;padding: 3px;'>0.10</td><td style='color:black;background-color:#9ce164;text-align:right;padding: 3px;'>0.77</td><td style='color:black;background-color:#ed9064;text-align:right;padding: 3px;'>0.13</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Reference</center></th><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.33</td><td style='color:black;background-color:#c6b764;text-align:right;padding: 3px;'>0.44</td><td style='color:black;background-color:#e29b64;text-align:right;padding: 3px;'>0.22</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Vascular cognitive impairment</center></th><td style='color:black;background-color:#dda064;text-align:right;padding: 3px;'>0.26</td><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.50</td><td style='color:black;background-color:#e09d64;text-align:right;padding: 3px;'>0.24</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '4'>
#             <center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Carotid occlusive disease</center></th><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.50</td><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.25</td><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.25</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Heart failure</center></th><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.25</td><td style='color:black;background-color:#bfbf64;text-align:right;padding: 3px;'>0.50</td><td style='color:black;background-color:#df9f64;text-align:right;padding: 3px;'>0.25</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Reference</center></th><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.33</td><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.33</td><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.33</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>Vascular cognitive impairment</center></th><td style='color:black;background-color:#fa8364;text-align:right;padding: 3px;'>0.03</td><td style='color:black;background-color:#b2cb64;text-align:right;padding: 3px;'>0.60</td><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.37</td></tr></table>

# %%
gnb.showTensor(bn_with_biomarkers.cpt(bn_with_biomarkers.idFromName("OUTCOME_MACE")), digits=2)
# Out:
# <table style="border:1px solid black;border-collapse: collapse;"><tr><th colspan='2'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>OUTCOME_MACE</center>
#       </th></tr><tr><th style='border:1px solid black;color:black;background-color:#808080'><center>PATIENT GROUP</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>MINI MENTAL STATE EXAMINATION</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>No</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Unobserved</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>Yes</center></th></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'>
#             <center>Carotid occlusive disease</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>(15;27[</center></th><td style='color:black;background-color:#dca164;text-align:right;padding: 3px;'>0.27</td><td style='color:black;background-color:#bac364;text-align:right;padding: 3px;'>0.54</td><td style='color:black;background-color:#e69764;text-align:right;padding: 3px;'>0.19</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[27;29[</center></th><td style='color:black;background-color:#dba264;text-align:right;padding: 3px;'>0.28</td><td style='color:black;background-color:#dba264;text-align:right;padding: 3px;'>0.28</td><td style='color:black;background-color:#c6b764;text-align:right;padding: 3px;'>0.44</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[29;30)</center></th><td style='color:black;background-color:#c8b564;text-align:right;padding: 3px;'>0.43</td><td style='color:black;background-color:#d7a664;text-align:right;padding: 3px;'>0.31</td><td style='color:black;background-color:#dda064;text-align:right;padding: 3px;'>0.27</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'>
#             <center>Heart failure</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>(15;27[</center></th><td style='color:black;background-color:#f58864;text-align:right;padding: 3px;'>0.07</td><td style='color:black;background-color:#9ae364;text-align:right;padding: 3px;'>0.79</td><td style='color:black;background-color:#ec9164;text-align:right;padding: 3px;'>0.14</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[27;29[</center></th><td style='color:black;background-color:#f58864;text-align:right;padding: 3px;'>0.08</td><td style='color:black;background-color:#aad364;text-align:right;padding: 3px;'>0.66</td><td style='color:black;background-color:#dda064;text-align:right;padding: 3px;'>0.26</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[29;30)</center></th><td style='color:black;background-color:#d8a564;text-align:right;padding: 3px;'>0.30</td><td style='color:black;background-color:#cab364;text-align:right;padding: 3px;'>0.41</td><td style='color:black;background-color:#daa364;text-align:right;padding: 3px;'>0.28</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'>
#             <center>Reference</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>(15;27[</center></th><td style='color:black;background-color:#d0ad64;text-align:right;padding: 3px;'>0.36</td><td style='color:black;background-color:#c4b964;text-align:right;padding: 3px;'>0.45</td><td style='color:black;background-color:#e79664;text-align:right;padding: 3px;'>0.18</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[27;29[</center></th><td style='color:black;background-color:#b4c964;text-align:right;padding: 3px;'>0.58</td><td style='color:black;background-color:#e49964;text-align:right;padding: 3px;'>0.21</td><td style='color:black;background-color:#e49964;text-align:right;padding: 3px;'>0.21</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[29;30)</center></th><td style='color:black;background-color:#aecf64;text-align:right;padding: 3px;'>0.63</td><td style='color:black;background-color:#dda064;text-align:right;padding: 3px;'>0.26</td><td style='color:black;background-color:#f08d64;text-align:right;padding: 3px;'>0.11</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '3'>
#             <center>Vascular cognitive impairment</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>(15;27[</center></th><td style='color:black;background-color:#eb9264;text-align:right;padding: 3px;'>0.15</td><td style='color:black;background-color:#b0cd64;text-align:right;padding: 3px;'>0.62</td><td style='color:black;background-color:#e19c64;text-align:right;padding: 3px;'>0.23</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[27;29[</center></th><td style='color:black;background-color:#df9e64;text-align:right;padding: 3px;'>0.24</td><td style='color:black;background-color:#c8b564;text-align:right;padding: 3px;'>0.42</td><td style='color:black;background-color:#d4a964;text-align:right;padding: 3px;'>0.33</td></tr><tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>[29;30)</center></th><td style='color:black;background-color:#ccb164;text-align:right;padding: 3px;'>0.40</td><td style='color:black;background-color:#cdb064;text-align:right;padding: 3px;'>0.38</td><td style='color:black;background-color:#e39a64;text-align:right;padding: 3px;'>0.22</td></tr></table>

# %%
# Initialize inference engine
ie = gum.LazyPropagation(bn_with_biomarkers)

# Get all variables in the network except the outcome
all_variables = bn_with_biomarkers.names()
variables_to_test = [var for var in all_variables if var != 'OUTCOME_MACE']

# Store results
mi_results = {}

for var in variables_to_test:
    try:
        it = gum.InformationTheory(ie, 'OUTCOME_MACE', [var])
        mi = it.mutualInformationXY()  # Without correction
        mi_results[var] = mi
        print(f'Mutual Information ({var} -> OUTCOME_MACE): {mi:.6f}')
    except Exception as e:
        print(f'Error processing variable {var}: {e}')

# Optional: sort results
sorted_mi = sorted(mi_results.items(), key=lambda x: x[1], reverse=True)

print("\nVariable Importance Ranking for OUTCOME_MACE (Raw Mutual Information)")
for var, score in sorted_mi:
    print(f'{var}: {score:.6f}')
# Out:
# Mutual Information (SMALL VESSEL DISEASE SCORE -> OUTCOME_MACE): 0.001863
# Mutual Information (BIOMARKER SCORE 2 -> OUTCOME_MACE): 0.000011
# Mutual Information (BASELINE CDR -> OUTCOME_MACE): 0.011984
# Mutual Information (GFAP -> OUTCOME_MACE): 0.000045
# Mutual Information (NFL -> OUTCOME_MACE): 0.000078
# Mutual Information (MINI MENTAL STATE EXAMINATION -> OUTCOME_MACE): 0.041821
# Mutual Information (STARKSTEIN SCORE -> OUTCOME_MACE): 0.000713
# Error processing variable DROPOUT REASON: [pyAgrum] Undefined element: The variable DROPOUT REASON(20) does not belong to this optimized inference.
# Mutual Information (HIPPOCAMPUS/INTRACRANIAL VOLUME -> OUTCOME_MACE): 0.000014
# Mutual Information (AB40 -> OUTCOME_MACE): 0.000224
# Mutual Information (BIOMARKER SCORE 1 -> OUTCOME_MACE): 0.000004
# Mutual Information (CEREBRAL BLOOD FLOW -> OUTCOME_MACE): 0.000045
# Mutual Information (PATIENT GROUP -> OUTCOME_MACE): 0.072435
# Mutual Information (AGE -> OUTCOME_MACE): 0.000123
# Mutual Information (PTAU181 -> OUTCOME_MACE): 0.000016
# Mutual Information (ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY -> OUTCOME_MACE): 0.005785
# Mutual Information (BRAIN/INTRACRANIAL VOLUME -> OUTCOME_MACE): 0.000047
# Mutual Information (OUTCOME_CDR_INCREASE -> OUTCOME_MACE): 0.010255
# Mutual Information (STROKE HISTORY -> OUTCOME_MACE): 0.001233
# Mutual Information (VASCULAR RISK SCORE -> OUTCOME_MACE): 0.000371
# Mutual Information (SEX -> OUTCOME_MACE): 0.000495
# Mutual Information (AB42 -> OUTCOME_MACE): 0.000059
#
# Variable Importance Ranking for OUTCOME_MACE (Raw Mutual Information)
# PATIENT GROUP: 0.072435
# MINI MENTAL STATE EXAMINATION: 0.041821
# BASELINE CDR: 0.011984
# OUTCOME_CDR_INCREASE: 0.010255
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.005785
# SMALL VESSEL DISEASE SCORE: 0.001863
# STROKE HISTORY: 0.001233
# STARKSTEIN SCORE: 0.000713
# SEX: 0.000495
# VASCULAR RISK SCORE: 0.000371
# AB40: 0.000224
# AGE: 0.000123
# NFL: 0.000078
# AB42: 0.000059
# BRAIN/INTRACRANIAL VOLUME: 0.000047
# CEREBRAL BLOOD FLOW: 0.000045
# GFAP: 0.000045
# PTAU181: 0.000016
# HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.000014
# BIOMARKER SCORE 2: 0.000011
# BIOMARKER SCORE 1: 0.000004

# %%
# Initialize inference engine
ie = gum.LazyPropagation(bn_with_biomarkers)

# Get all variables in the network except the outcome
all_variables = bn_with_biomarkers.names()
variables_to_test = [var for var in all_variables if var != 'OUTCOME_CDR_INCREASE']

# Store results
mi_results = {}

for var in variables_to_test:
    try:
        it = gum.InformationTheory(ie, 'OUTCOME_CDR_INCREASE', [var])
        mi = it.mutualInformationXY()  # Without correction
        mi_results[var] = mi
        print(f'Mutual Information ({var} -> OUTCOME_CDR_INCREASE): {mi:.6f}')
    except Exception as e:
        print(f'Error processing variable {var}: {e}')

# Optional: sort results
sorted_mi = sorted(mi_results.items(), key=lambda x: x[1], reverse=True)

print("\nVariable Importance Ranking for OUTCOME_CDR_INCREASE (Raw Mutual Information)")
for var, score in sorted_mi:
    print(f'{var}: {score:.6f}')
# Out:
# Mutual Information (SMALL VESSEL DISEASE SCORE -> OUTCOME_CDR_INCREASE): 0.005771
# Mutual Information (BIOMARKER SCORE 2 -> OUTCOME_CDR_INCREASE): 0.000022
# Mutual Information (BASELINE CDR -> OUTCOME_CDR_INCREASE): 0.037253
# Mutual Information (GFAP -> OUTCOME_CDR_INCREASE): 0.000101
# Mutual Information (NFL -> OUTCOME_CDR_INCREASE): 0.000145
# Mutual Information (OUTCOME_MACE -> OUTCOME_CDR_INCREASE): 0.010255
# Mutual Information (MINI MENTAL STATE EXAMINATION -> OUTCOME_CDR_INCREASE): 0.005740
# Mutual Information (STARKSTEIN SCORE -> OUTCOME_CDR_INCREASE): 0.001915
# Error processing variable DROPOUT REASON: [pyAgrum] Undefined element: The variable DROPOUT REASON(20) does not belong to this optimized inference.
# Mutual Information (HIPPOCAMPUS/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE): 0.000036
# Mutual Information (AB40 -> OUTCOME_CDR_INCREASE): 0.000261
# Mutual Information (BIOMARKER SCORE 1 -> OUTCOME_CDR_INCREASE): 0.000008
# Mutual Information (CEREBRAL BLOOD FLOW -> OUTCOME_CDR_INCREASE): 0.000056
# Mutual Information (PATIENT GROUP -> OUTCOME_CDR_INCREASE): 0.126471
# Mutual Information (AGE -> OUTCOME_CDR_INCREASE): 0.000328
# Mutual Information (PTAU181 -> OUTCOME_CDR_INCREASE): 0.000033
# Mutual Information (ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY -> OUTCOME_CDR_INCREASE): 0.006420
# Mutual Information (BRAIN/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE): 0.000118
# Mutual Information (STROKE HISTORY -> OUTCOME_CDR_INCREASE): 0.003092
# Mutual Information (VASCULAR RISK SCORE -> OUTCOME_CDR_INCREASE): 0.000871
# Mutual Information (SEX -> OUTCOME_CDR_INCREASE): 0.000611
# Mutual Information (AB42 -> OUTCOME_CDR_INCREASE): 0.000067
#
# Variable Importance Ranking for OUTCOME_CDR_INCREASE (Raw Mutual Information)
# PATIENT GROUP: 0.126471
# BASELINE CDR: 0.037253
# OUTCOME_MACE: 0.010255
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.006420
# SMALL VESSEL DISEASE SCORE: 0.005771
# MINI MENTAL STATE EXAMINATION: 0.005740
# STROKE HISTORY: 0.003092
# STARKSTEIN SCORE: 0.001915
# VASCULAR RISK SCORE: 0.000871
# SEX: 0.000611
# AGE: 0.000328
# AB40: 0.000261
# NFL: 0.000145
# BRAIN/INTRACRANIAL VOLUME: 0.000118
# GFAP: 0.000101
# AB42: 0.000067
# CEREBRAL BLOOD FLOW: 0.000056
# HIPPOCAMPUS/INTRACRANIAL VOLUME: 0.000036
# PTAU181: 0.000033
# BIOMARKER SCORE 2: 0.000022
# BIOMARKER SCORE 1: 0.000008

# %%
# Initialize inference engine
ie = gum.LazyPropagation(bn_with_biomarkers)

# Get the parents of OUTCOME_CDR_INCREASE
parents = bn_with_biomarkers.parents(bn_with_biomarkers.idFromName('OUTCOME_CDR_INCREASE'))
parent_names = [bn_with_biomarkers.variable(p).name() for p in parents]

# Get all variables in the network except OUTCOME_CDR_INCREASE and its parents
all_variables = bn_with_biomarkers.names()
variables_to_test = [var for var in all_variables if var != 'OUTCOME_CDR_INCREASE' and var not in parent_names]

# Initialize dictionary to store results
cmi_results = {}

# Loop through each variable and compute conditional mutual information
for var in variables_to_test:
    try:
        it = gum.InformationTheory(ie, 'OUTCOME_CDR_INCREASE', [var], parent_names)
        cmi = it.mutualInformationXYgivenZ()
        cmi_results[var] = cmi
        print(f'Corrected MI ({var} -> OUTCOME_CDR_INCREASE | {parent_names}): {cmi:.6f}')
    except Exception as e:
        print(f'Error processing variable {var}: {e}')

# Optional: sort and display ranking
sorted_cmi = sorted(cmi_results.items(), key=lambda x: x[1], reverse=True)

print("\nVariable Importance Ranking for OUTCOME_CDR_INCREASE (Corrected Mutual Information)")
for var, score in sorted_cmi:
    print(f'{var}: {score:.6f}')
# Out:
# Corrected MI (SMALL VESSEL DISEASE SCORE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (BIOMARKER SCORE 2 -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (GFAP -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (NFL -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (OUTCOME_MACE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (MINI MENTAL STATE EXAMINATION -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (STARKSTEIN SCORE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (DROPOUT REASON -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.207822
# Corrected MI (HIPPOCAMPUS/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (AB40 -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (BIOMARKER SCORE 1 -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (CEREBRAL BLOOD FLOW -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (AGE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (PTAU181 -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (BRAIN/INTRACRANIAL VOLUME -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (STROKE HISTORY -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (VASCULAR RISK SCORE -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
# Corrected MI (SEX -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): -0.000000
# Corrected MI (AB42 -> OUTCOME_CDR_INCREASE | ['BASELINE CDR', 'PATIENT GROUP']): 0.000000
#
# Variable Importance Ranking for OUTCOME_CDR_INCREASE (Corrected Mutual Information)
# DROPOUT REASON: 0.207822
# CEREBRAL BLOOD FLOW: 0.000000
# ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY: 0.000000
# AGE: 0.000000
# AB42: 0.000000
# BIOMARKER SCORE 2: 0.000000
# VASCULAR RISK SCORE: 0.000000
# STARKSTEIN SCORE: 0.000000
# PTAU181: 0.000000
# OUTCOME_MACE: 0.000000
# NFL: 0.000000
# BRAIN/INTRACRANIAL VOLUME: 0.000000
# SMALL VESSEL DISEASE SCORE: 0.000000
# GFAP: 0.000000
# AB40: -0.000000
# STROKE HISTORY: -0.000000
# HIPPOCAMPUS/INTRACRANIAL VOLUME: -0.000000
# BIOMARKER SCORE 1: -0.000000
# SEX: -0.000000
# MINI MENTAL STATE EXAMINATION: -0.000000

# %% [markdown]
# ## 8. Scenario Exploration
#
# Explore illustrative patient trajectories via direct inference and narrative summaries.

# %% [markdown]
# ### 8.1 Bootstrapped outcome risks
#
# Quantify uncertainty around the scenario-level outcome probabilities by refitting the joint network on bootstrap resamples and re-running inference for each patient profile.

# %%
from collections import defaultdict

def bootstrap_scenario_risks(
    df,
    scenario_profiles,
    target_outcomes,
    build_bn_func,
    layer_map,
    type_processor,
    n_bootstraps=200,
    score='K2',
    use_tabu=True,
    random_seed=42,
):
    samples = defaultdict(list)
    outcome_state_labels = {}
    failed = 0

    for i in range(n_bootstraps):
        seed = random_seed + i
        boot_df = df.sample(frac=1.0, replace=True, random_state=seed)
        try:
            bn_iter = build_bn_func(
                boot_df,
                outcomes=['OUTCOME_CDR_INCREASE', 'OUTCOME_MACE', 'DROPOUT REASON'],
                layer_map=layer_map,
                type_processor=type_processor,
                score=score,
                use_tabu=use_tabu,
                random_seed=seed,
            )
        except Exception:
            failed += 1
            continue

        for scenario_name, evidence in scenario_profiles:
            ie = gum.LazyPropagation(bn_iter)
            try:
                ie.setEvidence(evidence)
            except gum.InvalidArgument:
                continue

            for outcome_name, outcome_label in target_outcomes:
                if outcome_name not in outcome_state_labels:
                    var = bn_iter.variable(bn_iter.idFromName(outcome_name))
                    outcome_state_labels[outcome_name] = list(var.labels())
                posterior = ie.posterior(outcome_name)
                for idx_state, state_label in enumerate(outcome_state_labels[outcome_name]):
                    samples[(scenario_name, outcome_name, state_label)].append(float(posterior[idx_state]))

    rows = []
    for (scenario_name, outcome_name, state_label), values in samples.items():
        values = np.asarray(values)
        values = values[np.isfinite(values)]
        if values.size == 0:
            continue
        rows.append(
            {
                'Scenario': scenario_name,
                'Outcome': dict(target_outcomes).get(outcome_name, outcome_name),
                'Category': state_label,
                'Mean probability': values.mean(),
                'Std': values.std(ddof=1) if values.size > 1 else 0.0,
                'CI 2.5%': np.quantile(values, 0.025),
                'CI 97.5%': np.quantile(values, 0.975),
                'Bootstraps': int(values.size),
            }
        )

    if failed:
        print(f"Warning: {failed} bootstrap fits failed and were skipped.")
    return pd.DataFrame(rows).sort_values(['Scenario', 'Outcome', 'Category']).reset_index(drop=True)

healthy_evs = {
    'PATIENT GROUP': 'Reference',
    'SMALL VESSEL DISEASE SCORE': '0',
    'AGE': '58',
    'MINI MENTAL STATE EXAMINATION': '29',
    'BASELINE CDR': '0',
    'SEX': 'Male',
}

ill_evs = {
    'PATIENT GROUP': 'Vascular cognitive impairment',
    'SMALL VESSEL DISEASE SCORE': '2',
    'AGE': '76',
    'BASELINE CDR': '0',
    'SEX': 'Female',
}

scenario_profiles = [
    ('Healthy profile', healthy_evs),
    ('Ill profile', ill_evs),
]

target_outcomes = [
    ('OUTCOME_CDR_INCREASE', 'CDR increase'),
    ('OUTCOME_MACE', 'MACE event'),
]

scenario_bootstrap_summary = bootstrap_scenario_risks(
    df=df_imp,
    scenario_profiles=scenario_profiles,
    target_outcomes=target_outcomes,
    build_bn_func=build_bn,
    layer_map=layer_map,
    type_processor=type_processor,
    n_bootstraps=200,
    score='K2',
    use_tabu=True,
    random_seed=42,
)

display(scenario_bootstrap_summary)
# Out:
#            Scenario       Outcome    Category  Mean probability       Std  \
# 0   Healthy profile  CDR increase          No          0.617295  0.083232
# 1   Healthy profile  CDR increase  Unobserved          0.277727  0.065379
# 2   Healthy profile  CDR increase         Yes          0.104978  0.050670
# 3   Healthy profile    MACE event          No          0.536801  0.077565
# 4   Healthy profile    MACE event  Unobserved          0.282481  0.051401
# 5   Healthy profile    MACE event         Yes          0.180718  0.047447
# 6       Ill profile  CDR increase          No          0.261274  0.048518
# 7       Ill profile  CDR increase  Unobserved          0.334591  0.064920
# 8       Ill profile  CDR increase         Yes          0.404135  0.076445
# 9       Ill profile    MACE event          No          0.287323  0.038243
# 10      Ill profile    MACE event  Unobserved          0.409832  0.066230
# 11      Ill profile    MACE event         Yes          0.302845  0.041588
#
#      CI 2.5%  CI 97.5%  Bootstraps
# 0   0.461913  0.803951         200
# 1   0.140701  0.384789         200
# 2   0.027700  0.203141         200
# 3   0.404131  0.674313         200
# 4   0.197252  0.379324         200
# 5   0.095522  0.263439         200
# 6   0.166117  0.349174         200
# 7   0.210514  0.467924         200
# 8   0.301494  0.582436         200
# 9   0.204016  0.364683         200
# 10  0.324847  0.573767         200
# 11  0.217743  0.373230         200

# %%
ie = gum.LazyPropagation(bn_joint)

# Healthy profile
healthy_evs = {
    'PATIENT GROUP': 'Reference',
    'SMALL VESSEL DISEASE SCORE': '0',
    'AGE': '58',
    'MINI MENTAL STATE EXAMINATION': '29',
    'BASELINE CDR': '0',
    'SEX': 'Male'
}

# Calculate probabilities for healthy patient
ie.setEvidence(healthy_evs)
healthy_posterior = ie.posterior('OUTCOME_CDR_INCREASE')
print("Healthy Patient - OUTCOME_CDR_INCREASE probabilities:")
healthy_posterior
# Out:
# Healthy Patient - OUTCOME_CDR_INCREASE probabilities:
# (pyagrum.Tensor@0x12e7e4f90)
#   OUTCOME_CDR_INCREASE       |
# No       |Unobserve|Yes      |
# ---------|---------|---------|
#  0.6587  | 0.2857  | 0.0556  |

# %%
# Calculate probabilities for healthy patient
ie.setEvidence(healthy_evs)
healthy_posterior = ie.posterior('OUTCOME_MACE')
print("Healthy Patient - OUTCOME_MACE probabilities:")
healthy_posterior
# Out:
# Healthy Patient - OUTCOME_MACE probabilities:
# (pyagrum.Tensor@0x12faeb530)
#   OUTCOME_MACE               |
# No       |Unobserve|Yes      |
# ---------|---------|---------|
#  0.6292  | 0.2584  | 0.1124  |

# %%
gnb.showInference(bn_joint, 
                  evs=healthy_evs, 
                  size="10!", 
                  nodeColor=node_colors, 
                  cmapNode=plt.get_cmap("coolwarm"))

# %%
ie = gum.LazyPropagation(bn_joint)

# Healthy profile
ill_evs = {
    'PATIENT GROUP': 'Vascular cognitive impairment',
    'SMALL VESSEL DISEASE SCORE': '2',
    'AGE': '76',
    'BASELINE CDR': '0',
    'SEX': 'Female'
}


# Calculate probabilities for ill patient
ie.setEvidence(ill_evs)
ill_posterior = ie.posterior('OUTCOME_CDR_INCREASE')
print("Ill Patient - OUTCOME_CDR_INCREASE probabilities:")
ill_posterior
# Out:
# Ill Patient - OUTCOME_CDR_INCREASE probabilities:
# (pyagrum.Tensor@0x12ee590c0)
#   OUTCOME_CDR_INCREASE       |
# No       |Unobserve|Yes      |
# ---------|---------|---------|
#  0.2075  | 0.2453  | 0.5472  |

# %%
# Calculate probabilities for ill patient
ie.setEvidence(ill_evs)
ill_posterior = ie.posterior('OUTCOME_MACE')
print("Ill Patient - OUTCOME_MACE probabilities:")
ill_posterior
# Out:
# Ill Patient - OUTCOME_MACE probabilities:
# (pyagrum.Tensor@0x12e7fe2c0)
#   OUTCOME_MACE               |
# No       |Unobserve|Yes      |
# ---------|---------|---------|
#  0.3329  | 0.4127  | 0.2545  |

# %%
gnb.showInference(bn_joint, evs=ill_evs, size="10!", nodeColor=node_colors, cmapNode=plt.get_cmap("coolwarm"))

# %% [markdown]
# ## 9. Persistence and Next Steps
#
# Export the trained network and outline follow-up visual summaries.

# %%
# Persist the joint network for reuse outside the notebook
gum.saveBN(bn_joint, "bn_joint.bifxml")  # You can also use .net or .xdsl
