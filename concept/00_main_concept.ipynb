# %% [markdown]
# # VCI-Bayes concept
#
# This placeholder notebook is reserved for the high-level narrative ("moeder-notebook") that walks through the Bayesian network concept and its rationale.
# Replace this text with the actual concept notebook when it is ready.
